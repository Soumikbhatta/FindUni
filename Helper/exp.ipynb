# %%
data_college=[
  {
    "test_cutoff": "1:80 | ",
    "final_placements_domestic_salary_avg": 2583000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1699000,
    "program_duration": 2,
    "institute_name": "indian institute of management ahmedabad",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy"
  },
  {
    "test_cutoff": "1:98.54      | ",
    "final_placements_domestic_salary_avg": 2560000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "faculty of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:85  | ",
    "final_placements_domestic_salary_avg": 2540000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 2000000,
    "program_duration": 2,
    "institute_name": "indian institute of management calcutta",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy"
  },
  {
    "test_cutoff": "1:99      | ",
    "final_placements_domestic_salary_avg": 2454000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 2300000,
    "program_duration": 2,
    "institute_name": "indian institute of management bangalore",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy"
  },
  {
    "test_cutoff": "1:99     | ",
    "final_placements_domestic_salary_avg": 2425000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 720000,
    "program_duration": 2,
    "institute_name": "indian institute of management lucknow",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Media & Communication, Sustainability \/ Environment"
  },
  {
    "test_cutoff": "1:98      | ",
    "final_placements_domestic_salary_avg": 2308000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1900000,
    "program_duration": 2,
    "institute_name": "indian institute of management kozhikode",
    "program_name": "post graduate program",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "kozhikode",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy"
  },
  {
    "test_cutoff": "1:85 | 2:85 | 5:85 %  | ",
    "final_placements_domestic_salary_avg": 2290000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 1750000,
    "program_duration": 2,
    "institute_name": "s.p. jain institute of management and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:85          | 2:85          | 5:650          | ",
    "final_placements_domestic_salary_avg": 2224000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 1960000,
    "program_duration": 1,
    "institute_name": "s.p. jain institute of management and research",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "1 Year",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:96    | ",
    "final_placements_domestic_salary_avg": 2205000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1600000,
    "program_duration": 2,
    "institute_name": "management development institute",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics, International Business"
  },
  {
    "test_cutoff": "1:90 | ",
    "final_placements_domestic_salary_avg": 2080000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 982000,
    "program_duration": 2,
    "institute_name": "iit bombay shailesh j.mehta school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics, International Business"
  },
  {
    "test_cutoff": "1:98   | ",
    "final_placements_domestic_salary_avg": 2079000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1610000,
    "program_duration": 2,
    "institute_name": "indian institute of management indore",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Media & Communication"
  },
  {
    "test_cutoff": "1:NA   | ",
    "final_placements_domestic_salary_avg": 2013000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 2200000,
    "program_duration": 2,
    "institute_name": "management development institute",
    "program_name": "post graduate program in international management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "International Business"
  },
  {
    "test_cutoff": "1:97       | ",
    "final_placements_domestic_salary_avg": 1977000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 870000,
    "program_duration": 2,
    "institute_name": "national institute of industrial engineering",
    "program_name": "post graduate diploma in industrial management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:NA      | 5:NA      | 6:NA      | ",
    "final_placements_domestic_salary_avg": 1964000,
    "tests_accepted": "CAT, GMAT, GRE",
    "tution_fees_local_country_student": 1650000,
    "program_duration": 1,
    "institute_name": "indian institute of management bangalore",
    "program_name": "post graduate program in public policy & management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "1 Year",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:NA    | ",
    "final_placements_domestic_salary_avg": 1935000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1600000,
    "program_duration": 2,
    "institute_name": "management development institute",
    "program_name": "post graduate diploma in human resource management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "1:98 | ",
    "final_placements_domestic_salary_avg": 1847000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 960000,
    "program_duration": 2,
    "institute_name": "indian institute of technology delhi",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics, Others"
  },
  {
    "test_cutoff": "1:95    | ",
    "final_placements_domestic_salary_avg": 1742000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1052000,
    "program_duration": 2,
    "institute_name": "iit kharagpur vinod gupta school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kharagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:NA       | 5:NA       | ",
    "final_placements_domestic_salary_avg": 1740000,
    "tests_accepted": "CAT, GMAT",
    "tution_fees_local_country_student": 1875000,
    "program_duration": 1,
    "institute_name": "indian institute of management shillong",
    "program_name": "post graduate program for executives (pgpexecutive -mbic)",
    "country_name": "India",
    "state_name": "meghalaya",
    "city_name": "shillong",
    "program_duration_text": "1 Year",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:97     | ",
    "final_placements_domestic_salary_avg": 1679000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1300000,
    "program_duration": 2,
    "institute_name": "indian institute of management shillong",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "meghalaya",
    "city_name": "shillong",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics, Sustainability \/ Environment"
  },
  {
    "test_cutoff": "1:95 | 7:95 | 10:NA  | ",
    "final_placements_domestic_salary_avg": 1645000,
    "tests_accepted": "CAT, MH-CET, Others",
    "tution_fees_local_country_student": 204000,
    "program_duration": 2,
    "institute_name": "jamnalal bajaj institute of management studies",
    "program_name": "msc finance",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance"
  },
  {
    "test_cutoff": "1:95.5    | 5:650    | 10:NA    | ",
    "final_placements_domestic_salary_avg": 1600000,
    "tests_accepted": "CAT, GMAT, Others",
    "tution_fees_local_country_student": 333000,
    "program_duration": 2,
    "institute_name": "indian institute of science",
    "program_name": "master of management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Information Technology, Business Analytics"
  },
  {
    "test_cutoff": "1:NA     | ",
    "final_placements_domestic_salary_avg": 1590000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 2250500,
    "program_duration": 2,
    "institute_name": "indian institute of management ahmedabad",
    "program_name": "post graduate program in food and agri-business management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA     | 5:NA     | 10:NA     | ",
    "final_placements_domestic_salary_avg": 1520000,
    "tests_accepted": "CAT, GMAT, Others",
    "tution_fees_local_country_student": 1100000,
    "program_duration": 1,
    "institute_name": "management development institute",
    "program_name": "executive post graduate diploma in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "1 Year",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:94 | ",
    "final_placements_domestic_salary_avg": 1502000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1010000,
    "program_duration": 2,
    "institute_name": "indian institute of management ranchi",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 1500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 146000,
    "program_duration": 2,
    "institute_name": "chetan dattaji gaikwad institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 7:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 1500000,
    "tests_accepted": "CAT, MAT, MH-CET, Others",
    "tution_fees_local_country_student": 48000,
    "program_duration": 2,
    "institute_name": "dhole patil college of engineering",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:95   | ",
    "final_placements_domestic_salary_avg": 1491000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1400000,
    "program_duration": 2,
    "institute_name": "indian institute of management tiruchirappalli",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "trichy",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:90 | ",
    "final_placements_domestic_salary_avg": 1453503,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1379600,
    "program_duration": 2,
    "institute_name": "indian institute of management raipur",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "raipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy"
  },
  {
    "test_cutoff": "1:93      | ",
    "final_placements_domestic_salary_avg": 1452000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1010000,
    "program_duration": 2,
    "institute_name": "indian institute of management ranchi",
    "program_name": "post graduate diploma in human resource management",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "1:90   | 2:94   | 5:NA   | ",
    "final_placements_domestic_salary_avg": 1431000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 2010000,
    "program_duration": 2,
    "institute_name": "xavier institute of management",
    "program_name": "post graduate program in business management",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneshwar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:89.2     | 2:NA     | 21:NA     | ",
    "final_placements_domestic_salary_avg": 1424000,
    "tests_accepted": "CAT, XAT, IRMASAT",
    "tution_fees_local_country_student": 1050000,
    "program_duration": 2,
    "institute_name": "institute of rural management",
    "program_name": "post graduate diploma in rural management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "anand",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA     | 2:NA | 3:NA | 4:NA | 5:NA     | 11:NA | ",
    "final_placements_domestic_salary_avg": 1343000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 1200000,
    "program_duration": 1,
    "institute_name": "international management institute",
    "program_name": "executive post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "1 Year",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy"
  },
  {
    "test_cutoff": "1:91.6    | 5:NA    | ",
    "final_placements_domestic_salary_avg": 1311000,
    "tests_accepted": "CAT, GMAT",
    "tution_fees_local_country_student": 1588000,
    "program_duration": 2,
    "institute_name": "international management institute",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources, General Management"
  },
  {
    "test_cutoff": "1:85      | 2:90      | 3:NA      | 5:650      | ",
    "final_placements_domestic_salary_avg": 1310000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1586000,
    "program_duration": 1,
    "institute_name": "great lakes institute of management",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "1 Year",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:NA        | 2:NA        | 5:NA       | 22:NA        | ",
    "final_placements_domestic_salary_avg": 1280000,
    "tests_accepted": "CAT, XAT, GMAT, MICAT",
    "tution_fees_local_country_student": 2000000,
    "program_duration": 2,
    "institute_name": "mica the school of ideas",
    "program_name": "post graduate diploma in management - communications",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Business Analytics, Media & Communication, Digital Media"
  },
  {
    "test_cutoff": "1:85  | ",
    "final_placements_domestic_salary_avg": 1261000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1365000,
    "program_duration": 2,
    "institute_name": "indian institute of management visakhapatnam",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "andhra pradesh",
    "city_name": "visakhapatnam",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:70       | 2:70       | 5:500       | ",
    "final_placements_domestic_salary_avg": 1250000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 1900000,
    "program_duration": 1,
    "institute_name": "institute of management technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "1 Year",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | ",
    "final_placements_domestic_salary_avg": 1250000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "taxila business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:93  | ",
    "final_placements_domestic_salary_avg": 1244000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "iit madras department of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:85 | ",
    "final_placements_domestic_salary_avg": 1241587,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1375000,
    "program_duration": 2,
    "institute_name": "indian institute of management nagpur",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:90  | ",
    "final_placements_domestic_salary_avg": 1225000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1592000,
    "program_duration": 2,
    "institute_name": "indian institute of management udaipur",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "udaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:85         | ",
    "final_placements_domestic_salary_avg": 1220000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1200000,
    "program_duration": 2,
    "institute_name": "indian institute of management amritsar",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "amritsar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:94 | ",
    "final_placements_domestic_salary_avg": 1217000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1513000,
    "program_duration": 2,
    "institute_name": "indian institute of management kashipur",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "uttarakhand",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Media & Communication"
  },
  {
    "test_cutoff": "1:90    | ",
    "final_placements_domestic_salary_avg": 1215000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 26000,
    "program_duration": 2,
    "institute_name": "department of financial studies university of delhi",
    "program_name": "master of business administration in finance",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:95.8    | ",
    "final_placements_domestic_salary_avg": 1215000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 25000,
    "program_duration": 2,
    "institute_name": "department of business economics university of delhi",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing"
  },
  {
    "test_cutoff": "1:94 | ",
    "final_placements_domestic_salary_avg": 1200000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1175000,
    "program_duration": 2,
    "institute_name": "indian institute of management sirmaur",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "himachal pradesh",
    "city_name": "sirmaur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:95 | ",
    "final_placements_domestic_salary_avg": 1185000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1380000,
    "program_duration": 2,
    "institute_name": "indian institute of management rohtak",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "rohtak",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics, Sustainability \/ Environment"
  },
  {
    "test_cutoff": "1:90  | ",
    "final_placements_domestic_salary_avg": 1172000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 30392,
    "program_duration": 2,
    "institute_name": "department of commerce delhi school of economics delhi university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "International Business"
  },
  {
    "test_cutoff": "2:92|1:90|5:NA|8:NA",
    "final_placements_domestic_salary_avg": 1150000,
    "tests_accepted": "XAT, CAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1540000,
    "program_duration": 2,
    "institute_name": "xavier institute of management",
    "program_name": "post graduate program in human resource management",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneshwar",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "1:94 | ",
    "final_placements_domestic_salary_avg": 1133000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1000000,
    "program_duration": 2,
    "institute_name": "indian institute of management sambalpur",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "sambalpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:70|5:500|2:70",
    "final_placements_domestic_salary_avg": 1126000,
    "tests_accepted": "CAT, GMAT, XAT",
    "tution_fees_local_country_student": 1260000,
    "program_duration": 2,
    "institute_name": "institute of management technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, General Management, International Business"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 5:NA   | ",
    "final_placements_domestic_salary_avg": 1122000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1698000,
    "program_duration": 2,
    "institute_name": "goa institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "goa",
    "city_name": "panaji",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 5:NA   | ",
    "final_placements_domestic_salary_avg": 1122000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1697875,
    "program_duration": 2,
    "institute_name": "goa institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "goa",
    "city_name": "panaji",
    "program_duration_text": "2 Years",
    "specialization_name": "Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA    | 2:NA    | 3:NA    | 5:NA    | ",
    "final_placements_domestic_salary_avg": 1121000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1435000,
    "program_duration": 1,
    "institute_name": "great lakes institute of management",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "1 Year",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, General Management, Business Analytics, Others"
  },
  {
    "test_cutoff": "1:90%   | ",
    "final_placements_domestic_salary_avg": 1120000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1380000,
    "program_duration": 2,
    "institute_name": "indian institute of management jammu",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "jammu and kashmir",
    "city_name": "Jammu",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:90  | 5:640  | 6:314  | 8:201  | ",
    "final_placements_domestic_salary_avg": 1113000,
    "tests_accepted": "CAT, GMAT, GRE, NMAT",
    "tution_fees_local_country_student": 1860000,
    "program_duration": 2,
    "institute_name": "sda bocconi asia center",
    "program_name": "international master in business",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:85 | 2:85  | 5:630 | ",
    "final_placements_domestic_salary_avg": 1106000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 1400000,
    "program_duration": 2,
    "institute_name": "t. a. pai management institute",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "manipal",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:85       | ",
    "final_placements_domestic_salary_avg": 1102000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 377000,
    "program_duration": 2,
    "institute_name": "iit kanpur department of industrial and management engineering",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:88 | ",
    "final_placements_domestic_salary_avg": 1100000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 169000,
    "program_duration": 2,
    "institute_name": "university business school panjab university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "chandigarh region",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 7:99.4 | ",
    "final_placements_domestic_salary_avg": 1092000,
    "tests_accepted": "CAT, MH-CET",
    "tution_fees_local_country_student": 134000,
    "program_duration": 2,
    "institute_name": "sydenham institute of management studies",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:90%   | ",
    "final_placements_domestic_salary_avg": 1090000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1060000,
    "program_duration": 2,
    "institute_name": "indian institute of management bodh gaya",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "bihar",
    "city_name": "bodh gaya",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics, Sustainability \/ Environment"
  },
  {
    "test_cutoff": "1:85.50           | 2:85.75           | 5:650           | ",
    "final_placements_domestic_salary_avg": 1080000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 1598000,
    "program_duration": 2,
    "institute_name": "fore school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Strategy, International Business, Media & Communication"
  },
  {
    "test_cutoff": "1:90   | ",
    "final_placements_domestic_salary_avg": 1068000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 31000,
    "program_duration": 2,
    "institute_name": "department of commerce mhrod delhi university",
    "program_name": "master of business administration (mhrod)",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "1:90 | ",
    "final_placements_domestic_salary_avg": 1033000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "iit roorkee department of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "roorkee",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:90      | 2:90      | 3:NA      | 5:NA      | ",
    "final_placements_domestic_salary_avg": 1014000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1176000,
    "program_duration": 2,
    "institute_name": "great lakes institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Strategy, Business Analytics, Others"
  },
  {
    "test_cutoff": "",
    "final_placements_domestic_salary_avg": 1008000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1629279,
    "program_duration": 2,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Data Sciences"
  },
  {
    "test_cutoff": "1:83     | 2:73     | 3:98     | 5:500     | ",
    "final_placements_domestic_salary_avg": 1008000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1629279,
    "program_duration": 2,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration (international business)",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "International Business"
  },
  {
    "test_cutoff": "1:83    | 2:73    | 3:98    | 5:500    | ",
    "final_placements_domestic_salary_avg": 1008000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1629279,
    "program_duration": 2,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration (retail management)",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Retail Management"
  },
  {
    "test_cutoff": "1:83    | 2:73    | 3:98    | 5:500    | ",
    "final_placements_domestic_salary_avg": 1008000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1629279,
    "program_duration": 2,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration (financial services)",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Financial Services "
  },
  {
    "test_cutoff": "1:83   | 2:73   | 3:98   | 5:500   | ",
    "final_placements_domestic_salary_avg": 1008000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1629279,
    "program_duration": 2,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration (integrated marketing communications)",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Integrated Marketing Communication"
  },
  {
    "test_cutoff": "1:NA|2:NA|5:NA",
    "final_placements_domestic_salary_avg": 1006000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 950000,
    "program_duration": 2,
    "institute_name": "t. a. pai management institute",
    "program_name": "post graduate diploma in healthcare and hospital management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "manipal",
    "program_duration_text": "2 Years",
    "specialization_name": "Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA|2:NA|5:NA",
    "final_placements_domestic_salary_avg": 1006000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 950000,
    "program_duration": 2,
    "institute_name": "t. a. pai management institute",
    "program_name": "post graduate diploma in banking & finance management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "manipal",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance"
  },
  {
    "test_cutoff": "1:NA|2:NA|5:NA",
    "final_placements_domestic_salary_avg": 1006000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 950000,
    "program_duration": 2,
    "institute_name": "t. a. pai management institute",
    "program_name": "post graduate diploma in human resource management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "manipal",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "1:70% | 2:70% | 3:80% | 4:80% | 5:570 | 6:286 | 8:160 | ",
    "final_placements_domestic_salary_avg": 1000000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, GRE, NMAT",
    "tution_fees_local_country_student": 1680000,
    "program_duration": 2,
    "institute_name": "woxsen school of business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Business Analytics"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 5:NA   | 11:NA   | ",
    "final_placements_domestic_salary_avg": 990000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, ATMA",
    "tution_fees_local_country_student": 930000,
    "program_duration": 2,
    "institute_name": "new delhi institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Media & Communication, Digital Media"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 4:NA   | 5:NA   | 6:NA   | 10:NA   | ",
    "final_placements_domestic_salary_avg": 974000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, GRE, Others",
    "tution_fees_local_country_student": 575000,
    "program_duration": 1,
    "institute_name": "praxis business school",
    "program_name": "post graduate program in business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "1 Year",
    "specialization_name": "Business Analytics"
  },
  {
    "test_cutoff": "1:80      | 2:NA      | ",
    "final_placements_domestic_salary_avg": 950000,
    "tests_accepted": "CAT, XAT",
    "tution_fees_local_country_student": 940000,
    "program_duration": 2,
    "institute_name": "loyola institute of business administration",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management, Business Analytics, International Business"
  },
  {
    "test_cutoff": "1:75 % | 3:75% | 4:89 | ",
    "final_placements_domestic_salary_avg": 944000,
    "tests_accepted": "CAT, CMAT, MAT",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "national institute of bank management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management, Business Analytics"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 4:NA   | 5:NA   | ",
    "final_placements_domestic_salary_avg": 937000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 1473000,
    "program_duration": 1,
    "institute_name": "school of inspired leadership",
    "program_name": "post graduate program in business leadership (pgp-bl)",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "1 Year",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:75%       | 2:75%       | 3:85%       | 5:85%       | 6:85%       | 8:80%    | ",
    "final_placements_domestic_salary_avg": 937000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, GRE, NMAT",
    "tution_fees_local_country_student": 1386000,
    "program_duration": 2,
    "institute_name": "ifmr graduate school of business (gsb), krea university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "andhra pradesh",
    "city_name": "Sricity",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Data Sciences, Economics, Finance Accounting and Quantitative Finance, Strategic Management"
  },
  {
    "test_cutoff": "1:86.5      | ",
    "final_placements_domestic_salary_avg": 930000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1450000,
    "program_duration": 2,
    "institute_name": "bharathidasan institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "trichy",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:85     | ",
    "final_placements_domestic_salary_avg": 920000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1209000,
    "program_duration": 2,
    "institute_name": "lal bahadur shastri institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:75 | 2:75 | 3:85   | 7:85   | 11:85   | ",
    "final_placements_domestic_salary_avg": 919000,
    "tests_accepted": "CAT, XAT, CMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 1100000,
    "program_duration": 2,
    "institute_name": "prin l.n. welingkar institute of management development and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:70      | 5:NA      | ",
    "final_placements_domestic_salary_avg": 918000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 1087000,
    "program_duration": 2,
    "institute_name": "department of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "Pilani",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA     | 2:NA     | 3:NA     | 5:NA     | ",
    "final_placements_domestic_salary_avg": 910000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1139000,
    "program_duration": 2,
    "institute_name": "great lakes institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, General Management, Others"
  },
  {
    "test_cutoff": "1:NA     | 2:NA     | 3:NA     | 5:NA     | ",
    "final_placements_domestic_salary_avg": 910000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1139000,
    "program_duration": 2,
    "institute_name": "great lakes institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, General Management, Business Analytics, Others"
  },
  {
    "test_cutoff": "1:85 | 2:85 | 3:85 | 5:85 | 7:85 | 11:85  | ",
    "final_placements_domestic_salary_avg": 906000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 1100000,
    "program_duration": 2,
    "institute_name": "prin l.n. welingkar institute of management development and research",
    "program_name": "post graduate diploma in e-business management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA   | ",
    "final_placements_domestic_salary_avg": 903000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1150000,
    "program_duration": 2,
    "institute_name": "management development institute",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "murshidababd",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:85    | 2:85    | 3:85    | 5:85    | 7:85    | 11:85    | ",
    "final_placements_domestic_salary_avg": 903000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 1100000,
    "program_duration": 2,
    "institute_name": "prin l.n. welingkar institute of management development and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:85 | 2:85 | 5:650 | 6:320 | 10:NA  | ",
    "final_placements_domestic_salary_avg": 896000,
    "tests_accepted": "CAT, XAT, GMAT, GRE, Others",
    "tution_fees_local_country_student": 595000,
    "program_duration": 1,
    "institute_name": "praxis business school",
    "program_name": "post graduate program in data science",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "1 Year",
    "specialization_name": "Business Analytics"
  },
  {
    "test_cutoff": "1:85 | 2:85 | 3:85 | 5:85 | 7:85 | 11:85 | ",
    "final_placements_domestic_salary_avg": 869000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 1100000,
    "program_duration": 2,
    "institute_name": "prin l.n. welingkar institute of management development and research",
    "program_name": "post graduate diploma in business design management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Others"
  },
  {
    "test_cutoff": "1:NA     | 2:NA     | 3:NA     | 4:NA     | 5:NA     | 8:NA     | 11:NA     | ",
    "final_placements_domestic_salary_avg": 850000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, NMAT, Others, ATMA",
    "tution_fees_local_country_student": 930000,
    "program_duration": 2,
    "institute_name": "itm business school",
    "program_name": "post graduate diploma in international business",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "navi mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 8:NA | ",
    "final_placements_domestic_salary_avg": 850000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, NMAT",
    "tution_fees_local_country_student": 817000,
    "program_duration": 2,
    "institute_name": "thiagarajar school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "madurai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management, Business Analytics"
  },
  {
    "test_cutoff": "1:85 | 2:85  | 3:85 | 5:85 | 7:85 | 11:85 | ",
    "final_placements_domestic_salary_avg": 848000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 1100000,
    "program_duration": 2,
    "institute_name": "prin l.n. welingkar institute of management development and research",
    "program_name": "post graduate diploma in e-business management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:NA | 3:NA | ",
    "final_placements_domestic_salary_avg": 823000,
    "tests_accepted": "CAT, CMAT",
    "tution_fees_local_country_student": 1125000,
    "program_duration": 2,
    "institute_name": "national insurance academy",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:80     | 5:NA     | ",
    "final_placements_domestic_salary_avg": 821000,
    "tests_accepted": "CAT, GMAT",
    "tution_fees_local_country_student": 952000,
    "program_duration": 2,
    "institute_name": "institute of management nirma university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Strategy, International Business"
  },
  {
    "test_cutoff": "1:70     | 2:70 | 3:95 | 5:70 | ",
    "final_placements_domestic_salary_avg": 814000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1200000,
    "program_duration": 2,
    "institute_name": "birla institute of management technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 5:NA | 8:NA | ",
    "final_placements_domestic_salary_avg": 800000,
    "tests_accepted": "CAT, XAT, MAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1350000,
    "program_duration": 2,
    "institute_name": "bml munjal university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Business Analytics"
  },
  {
    "test_cutoff": "1:65 | 2:65 | 3:90 | 5:65 | ",
    "final_placements_domestic_salary_avg": 787000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1150000,
    "program_duration": 2,
    "institute_name": "birla institute of management technology",
    "program_name": "post graduate diploma in international business",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, International Business"
  },
  {
    "test_cutoff": "1:30     | ",
    "final_placements_domestic_salary_avg": 780000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 825000,
    "program_duration": 2,
    "institute_name": "national institute of agricultural extension management",
    "program_name": "post graduate diploma in agri business management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA    | 2:NA    | 3:NA    | 4:NA    | 5:NA    | 8:NA    | 11:NA    | ",
    "final_placements_domestic_salary_avg": 780000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, NMAT, ATMA",
    "tution_fees_local_country_student": 1350000,
    "program_duration": 2,
    "institute_name": "alliance school of business alliance university",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Digital Media, E-Commerce"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 5:NA   | ",
    "final_placements_domestic_salary_avg": 780000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 1400000,
    "program_duration": 2,
    "institute_name": "school of inspired leadership",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:60 | 2:60 | 3:70 | 4:70 | 5:60 | ",
    "final_placements_domestic_salary_avg": 773000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 900000,
    "program_duration": 2,
    "institute_name": "birla institute of management technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Retail Management"
  },
  {
    "test_cutoff": "1:60 | 2:60 | 3:70 | 4:70 | 5:60 | ",
    "final_placements_domestic_salary_avg": 767000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 900000,
    "program_duration": 2,
    "institute_name": "birla institute of management technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Insurance Business Management"
  },
  {
    "test_cutoff": "1:80   | 2:80   | 3:NA   | 5:NA   | ",
    "final_placements_domestic_salary_avg": 764000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1400000,
    "program_duration": 2,
    "institute_name": "institute of management technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:70% | 2:60% | ",
    "final_placements_domestic_salary_avg": 762000,
    "tests_accepted": "CAT, XAT",
    "tution_fees_local_country_student": 1020000,
    "program_duration": 2,
    "institute_name": "international school of business and media",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Media & Communication"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 5:NA  | ",
    "final_placements_domestic_salary_avg": 750000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 915000,
    "program_duration": 2,
    "institute_name": "ifim business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:78.32   | 2:NA   | ",
    "final_placements_domestic_salary_avg": 750000,
    "tests_accepted": "CAT, XAT",
    "tution_fees_local_country_student": 624000,
    "program_duration": 2,
    "institute_name": "indian institute of forest management",
    "program_name": "post graduate diploma in forestry management",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "bhopal",
    "program_duration_text": "2 Years",
    "specialization_name": "Forest Management"
  },
  {
    "test_cutoff": "1:NA  | 2:65  | 3:NA  | ",
    "final_placements_domestic_salary_avg": 750000,
    "tests_accepted": "CAT, XAT, CMAT",
    "tution_fees_local_country_student": 965000,
    "program_duration": 2,
    "institute_name": "xavier institute of social service xiss",
    "program_name": "post graduate diploma in human resource management",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 750000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others",
    "tution_fees_local_country_student": 340000,
    "program_duration": 2,
    "institute_name": "jaipur national university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Agri \/ Food \/ Rural Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 750000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 242000,
    "program_duration": 2,
    "institute_name": "arya college of engineering and information technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 750000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET",
    "tution_fees_local_country_student": 660000,
    "program_duration": 2,
    "institute_name": "balaji institute of management and human resource development",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 740000,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 130000,
    "program_duration": 2,
    "institute_name": "vivekananda global university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:60      | 5:550      | 8:NA      | 12:90      | ",
    "final_placements_domestic_salary_avg": 732000,
    "tests_accepted": "CAT, GMAT, NMAT, IBSAT",
    "tution_fees_local_country_student": 1404000,
    "program_duration": 2,
    "institute_name": "icfai business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|5:NA|8:NA|10:NA",
    "final_placements_domestic_salary_avg": 732000,
    "tests_accepted": "CAT, XAT, GMAT, NMAT, Others",
    "tution_fees_local_country_student": 1200000,
    "program_duration": 2,
    "institute_name": "xavier school of rural management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneshwar",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 4:NA   | 7:99.71   | 11:NA   | ",
    "final_placements_domestic_salary_avg": 728000,
    "tests_accepted": "CAT, XAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 900000,
    "program_duration": 2,
    "institute_name": "sies college of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "navi mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 728000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 670000,
    "program_duration": 2,
    "institute_name": "vivekanand education society's institute of management studies and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 4:NA   | 5:NA   | 7:NA   | 11:NA   | ",
    "final_placements_domestic_salary_avg": 728000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 446000,
    "program_duration": 2,
    "institute_name": "vivekanand education society's institute of management studies and research",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:79.31   | ",
    "final_placements_domestic_salary_avg": 720000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 99000,
    "program_duration": 2,
    "institute_name": "faculty of management studies banaras hindu university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "varanasi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA|5:NA|6:NA|2:NA|3:NA",
    "final_placements_domestic_salary_avg": 720000,
    "tests_accepted": "CAT, GMAT, GRE, XAT, CMAT",
    "tution_fees_local_country_student": 600000,
    "program_duration": 2,
    "institute_name": "centre for management studies nalsar university of law",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 5:NA   | ",
    "final_placements_domestic_salary_avg": 717000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 1200000,
    "program_duration": 2,
    "institute_name": "institute of management technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:70  | 2:70     | 3:80     | 4:90  | 5:550  | 11:90  | ",
    "final_placements_domestic_salary_avg": 715000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 927000,
    "program_duration": 2,
    "institute_name": "praxis business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics, E-Commerce"
  },
  {
    "test_cutoff": "1:70  | 2:70  | 3:NA  | 5:NA  | 8:NA  | ",
    "final_placements_domestic_salary_avg": 714000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1095000,
    "program_duration": 2,
    "institute_name": "sdm institute of management development",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "mysore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:70 | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 708000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "xavier institute of management and entrepreneurship",
    "program_name": "post graduate diploma in finance management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 4:NA   | 5:75% | 11:NA   | ",
    "final_placements_domestic_salary_avg": 704000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 1000000,
    "program_duration": 2,
    "institute_name": "xavier institute of management and entrepreneurship",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Operations \/ SCM \/ Production"
  },
  {
    "test_cutoff": "1:64  | 3:NA  | ",
    "final_placements_domestic_salary_avg": 700000,
    "tests_accepted": "CAT, CMAT",
    "tution_fees_local_country_student": 680000,
    "program_duration": 2,
    "institute_name": "choudhary charan singh national institute of agricultural marketing",
    "program_name": "post graduate diploma in agri business management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 8:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 700000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, NMAT, ATMA",
    "tution_fees_local_country_student": 1350000,
    "program_duration": 2,
    "institute_name": "alliance school of business alliance university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Strategy, Hospitality \/ Tourism, International Business, Retail Management, Media & Communication, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | 16:NA | ",
    "final_placements_domestic_salary_avg": 700000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA, TANCET",
    "tution_fees_local_country_student": 650000,
    "program_duration": 2,
    "institute_name": "crescent school of business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:50   | 2:50 | 3:50   | 4:50   | 5:400 | 6:270   | 8:160   | 10:NA   | 11:50   | ",
    "final_placements_domestic_salary_avg": 700000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, GRE, NMAT, Others, ATMA",
    "tution_fees_local_country_student": 1100000,
    "program_duration": 2,
    "institute_name": "jindal global business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "sonepat",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|3:NA|5:NA|11:NA",
    "final_placements_domestic_salary_avg": 700000,
    "tests_accepted": "CAT, XAT, MAT, CMAT, GMAT, ATMA",
    "tution_fees_local_country_student": 760000,
    "program_duration": 2,
    "institute_name": "adani institute of infrastructure management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Infrastructure \/ Real Estate"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 14:NA | 17:NA | ",
    "final_placements_domestic_salary_avg": 700000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, KMAT, PGCET",
    "tution_fees_local_country_student": 762000,
    "program_duration": 2,
    "institute_name": "aditya institute of management studies and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 700000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 610500,
    "program_duration": 2,
    "institute_name": "doon business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 700000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 645000,
    "program_duration": 2,
    "institute_name": "deviprasad goenka management college of media studies",
    "program_name": "post graduate diploma in media & communication management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Media & Communication"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 700000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET",
    "tution_fees_local_country_student": 660000,
    "program_duration": 2,
    "institute_name": "balaji institute of telecom and management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Operations \/ SCM \/ Production, Business Analytics"
  },
  {
    "test_cutoff": "1:83  | ",
    "final_placements_domestic_salary_avg": 690000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 317000,
    "program_duration": 2,
    "institute_name": "nit trichy department of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "trichy",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:60 | 2:70   | 3:70   | 4:600   | 5:450   | 6:300   | 11:70   | ",
    "final_placements_domestic_salary_avg": 685000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, GRE, ATMA",
    "tution_fees_local_country_student": 769000,
    "program_duration": 2,
    "institute_name": "christ university institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 5:NA  | ",
    "final_placements_domestic_salary_avg": 684000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 885000,
    "program_duration": 2,
    "institute_name": "international management institute",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneswar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 680000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 895000,
    "program_duration": 2,
    "institute_name": "itm business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 675000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 965000,
    "program_duration": 2,
    "institute_name": "asia pacific institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "4:NA|1:NA|3:NA|2:NA|5:NA|11:NA",
    "final_placements_domestic_salary_avg": 675000,
    "tests_accepted": "MAT, CAT, CMAT, XAT, GMAT, ATMA",
    "tution_fees_local_country_student": 1410000,
    "program_duration": 2,
    "institute_name": "iilm institute for higher education",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 675000,
    "tests_accepted": "CAT, CMAT, MAT",
    "tution_fees_local_country_student": 810000,
    "program_duration": 2,
    "institute_name": "iilm institute for business and management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 675000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 198000,
    "program_duration": 2,
    "institute_name": "kejriwal institute of management and development studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 670000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 700000,
    "program_duration": 2,
    "institute_name": "christ institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA|11:NA|4:NA|5:NA",
    "final_placements_domestic_salary_avg": 670000,
    "tests_accepted": "CAT, XAT, CMAT, ATMA, MAT, GMAT",
    "tution_fees_local_country_student": 1000000,
    "program_duration": 2,
    "institute_name": "xavier institute of management and entrepreneurship",
    "program_name": "post graduate diploma in human resource management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA|11:NA|4:NA|5:NA",
    "final_placements_domestic_salary_avg": 670000,
    "tests_accepted": "CAT, XAT, CMAT, ATMA, MAT, GMAT",
    "tution_fees_local_country_student": 1000000,
    "program_duration": 2,
    "institute_name": "xavier institute of management and entrepreneurship",
    "program_name": "post graduate diploma in marketing management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA|11:NA|4:NA|5:NA",
    "final_placements_domestic_salary_avg": 670000,
    "tests_accepted": "CAT, XAT, CMAT, ATMA, MAT, GMAT",
    "tution_fees_local_country_student": 1000000,
    "program_duration": 2,
    "institute_name": "xavier institute of management and entrepreneurship",
    "program_name": "post graduate diploma in international business & business analytics",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Business Analytics, International Business"
  },
  {
    "test_cutoff": "2:NA|4:NA|3:NA|7:NA|1:NA",
    "final_placements_domestic_salary_avg": 669000,
    "tests_accepted": "XAT, MAT, CMAT, MH-CET, CAT",
    "tution_fees_local_country_student": 1060000,
    "program_duration": 2,
    "institute_name": "the foundation for liberal and management education",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:85 | 2:85 | 4:650 | 5:550 | 8:60 | ",
    "final_placements_domestic_salary_avg": 667000,
    "tests_accepted": "CAT, XAT, MAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1344000,
    "program_duration": 2,
    "institute_name": "amity business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "gautam buddha nagar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "2:NA|4:NA|3:NA|7:NA|1:NA",
    "final_placements_domestic_salary_avg": 664000,
    "tests_accepted": "XAT, MAT, CMAT, MH-CET, CAT",
    "tution_fees_local_country_student": 1160000,
    "program_duration": 2,
    "institute_name": "the foundation for liberal and management education",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|5:NA|4:NA|8:NA",
    "final_placements_domestic_salary_avg": 660000,
    "tests_accepted": "CAT, XAT, GMAT, MAT, NMAT",
    "tution_fees_local_country_student": 1300000,
    "program_duration": 2,
    "institute_name": "bml munjal university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 5:NA  | ",
    "final_placements_domestic_salary_avg": 654000,
    "tests_accepted": "CAT, XAT, GMAT",
    "tution_fees_local_country_student": 976000,
    "program_duration": 2,
    "institute_name": "international management institute",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET",
    "tution_fees_local_country_student": 4220000,
    "program_duration": 2,
    "institute_name": "balaji institute of modern management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production"
  },
  {
    "test_cutoff": "1:NA      | 2:NA      | 3:NA      | 4:NA      | 7:97.76      | 11:NA      | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 930000,
    "program_duration": 2,
    "institute_name": "n. l. dalmia institute of management studies and research",
    "program_name": "post graduate diploma in business management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 1035000,
    "program_duration": 2,
    "institute_name": "teri university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Sustainability \/ Environment"
  },
  {
    "test_cutoff": "1:NA|5:NA|3:NA|10:NA",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, GMAT, CMAT, Others",
    "tution_fees_local_country_student": 848000,
    "program_duration": 2,
    "institute_name": "universal business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "karjat",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA     | 2:NA     | 3:NA     | 4:NA     | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 720000,
    "program_duration": 2,
    "institute_name": "gitam school of international business",
    "program_name": "master of business administration (international business)",
    "country_name": "India",
    "state_name": "andhra pradesh",
    "city_name": "visakhapatnam",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Operations \/ SCM \/ Production, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 510000,
    "program_duration": 2,
    "institute_name": "accurate institute of management and technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 588000,
    "program_duration": 2,
    "institute_name": "shanti business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Agri \/ Food \/ Rural Business, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 419000,
    "program_duration": 2,
    "institute_name": "lovely professional university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "jalandhar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Strategy, Business Analytics, Healthcare \/ Hospital \/ Pharma, International Business, Retail Management, E-Commerce, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 5:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, MAT, GMAT, Others, ATMA",
    "tution_fees_local_country_student": 495000,
    "program_duration": 2,
    "institute_name": "institute of business studies and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "navi mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 250000,
    "program_duration": 2,
    "institute_name": "kiit school of rural management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneshwar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:700 | 5:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "iilm college of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Strategy, International Business, Media & Communication, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|2:NA|10:NA|11:NA",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "MAT, CAT, XAT, Others, ATMA",
    "tution_fees_local_country_student": 130000,
    "program_duration": 2,
    "institute_name": "krupajal management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneswar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 1100000,
    "program_duration": 2,
    "institute_name": "taxila business school",
    "program_name": "post graduate diploma in business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "International Business"
  },
  {
    "test_cutoff": "1:NA|5:NA|3:NA|10:NA",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, GMAT, CMAT, Others",
    "tution_fees_local_country_student": 1098000,
    "program_duration": 2,
    "institute_name": "universal business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "karjat",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management, Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, Others, ATMA",
    "tution_fees_local_country_student": 761000,
    "program_duration": 2,
    "institute_name": "aditya institute of management studies and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Digital Media"
  },
  {
    "test_cutoff": "1:NA    | 2:NA    | 3:NA    | 4:NA    | 5:NA    | 7:NA    | 11:NA    | ",
    "final_placements_domestic_salary_avg": 650000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "aditya institute of management studies and research",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:50  | 2:50 | 3:50 | 4:50  | 5:NA    | 11:50 | ",
    "final_placements_domestic_salary_avg": 646000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 890000,
    "program_duration": 2,
    "institute_name": "fortune institute of international business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Strategy, Business Analytics, International Business"
  },
  {
    "test_cutoff": "7:97% | ",
    "final_placements_domestic_salary_avg": 643000,
    "tests_accepted": "CAT, CMAT, MH-CET",
    "tution_fees_local_country_student": 130000,
    "program_duration": 2,
    "institute_name": "department of management sciences",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | ",
    "final_placements_domestic_salary_avg": 640000,
    "tests_accepted": "CAT, XAT",
    "tution_fees_local_country_student": 746000,
    "program_duration": 2,
    "institute_name": "pandit deendayal petroleum university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "gandhinagar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Power \/ Energy \/ Oil \/ Gas, Infrastructure \/ Real Estate"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 4:NA   | 5:60 | 11:NA   | ",
    "final_placements_domestic_salary_avg": 628000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "xavier institute of management and entrepreneurship",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 5:NA | 6:NA | ",
    "final_placements_domestic_salary_avg": 625000,
    "tests_accepted": "CAT, XAT, GMAT, GRE",
    "tution_fees_local_country_student": 1060000,
    "program_duration": 2,
    "institute_name": "amrita school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:75 | 2:70  | 3:70 | 4:580 | 11:60 | ",
    "final_placements_domestic_salary_avg": 625000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 715000,
    "program_duration": 2,
    "institute_name": "jagan institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 5:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 625000,
    "tests_accepted": "CAT, CMAT, GMAT, Others",
    "tution_fees_local_country_student": 900000,
    "program_duration": 2,
    "institute_name": "national institute of construction management and research",
    "program_name": "post graduate programs in advanced construction management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Infrastructure \/ Real Estate"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 625000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 700000,
    "program_duration": 2,
    "institute_name": "mile management institute for leadership and excellence",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 620000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, Others, ATMA",
    "tution_fees_local_country_student": 615000,
    "program_duration": 2,
    "institute_name": "vishwa vishwani institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 4:NA  | 11:NA  | 17:NA  | ",
    "final_placements_domestic_salary_avg": 620000,
    "tests_accepted": "CAT, XAT, MAT, ATMA, PGCET",
    "tution_fees_local_country_student": 900000,
    "program_duration": 2,
    "institute_name": "isbr business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, International Business, Retail Management, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 620000,
    "tests_accepted": "CAT, XAT, MAT, ATMA",
    "tution_fees_local_country_student": 720000,
    "program_duration": 2,
    "institute_name": "asian business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 620000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "international school of business and media",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Media & Communication"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 620000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA, JMET",
    "tution_fees_local_country_student": 700000,
    "program_duration": 2,
    "institute_name": "mulshi institute of business management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Media & Communication"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 620000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 700000,
    "program_duration": 2,
    "institute_name": "international school of business and media",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:80 | 2:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 619000,
    "tests_accepted": "CAT, XAT, MAT, ATMA",
    "tution_fees_local_country_student": 330000,
    "program_duration": 2,
    "institute_name": "master school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "meerut",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 614000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 525000,
    "program_duration": 2,
    "institute_name": "kiit school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneshwar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 613000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 780000,
    "program_duration": 2,
    "institute_name": "institute for future education entrepreneurship and leadership",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:75% | 2:75% | 4:500 | 5:500 | 8:60 | ",
    "final_placements_domestic_salary_avg": 610000,
    "tests_accepted": "CAT, XAT, MAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1190000,
    "program_duration": 2,
    "institute_name": "rics school of built environment amity university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Strategy"
  },
  {
    "test_cutoff": "3:NA              | 5:NA              | 11:NA                | ",
    "final_placements_domestic_salary_avg": 610000,
    "tests_accepted": "CAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 795000,
    "program_duration": 2,
    "institute_name": "institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Retail Management, Finance & Banking"
  },
  {
    "test_cutoff": "1:NA|4:NA|3:NA|5:NA|2:NA|6:NA",
    "final_placements_domestic_salary_avg": 602000,
    "tests_accepted": "CAT, MAT, CMAT, GMAT, XAT, GRE",
    "tution_fees_local_country_student": 650000,
    "program_duration": 2,
    "institute_name": "amrita school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "kollam",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:80  | 3:NA  | 4:NA  | 5:NA  | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 600000,
    "program_duration": 2,
    "institute_name": "indian institute of social welfare and business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:82|3:NA",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, CMAT",
    "tution_fees_local_country_student": 168000,
    "program_duration": 2,
    "institute_name": "nit durgapur department of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "durgapur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT",
    "tution_fees_local_country_student": 630000,
    "program_duration": 2,
    "institute_name": "chandragupt institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "bihar",
    "city_name": "patna",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, General Management, Business Analytics"
  },
  {
    "test_cutoff": "1:50 | 2:50 | 3:NA | 4:NA | 5:NA | 16:NA | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, TANCET",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "school of management srm university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 575000,
    "program_duration": 2,
    "institute_name": "gl bajaj institute of management and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA|4:NA|5:NA",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "st. joseph's college of business administration",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 725000,
    "program_duration": 2,
    "institute_name": "apeejay school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 7:NA  | 8:NA  | 10:NA  | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, NMAT, Others",
    "tution_fees_local_country_student": 1200000,
    "program_duration": 2,
    "institute_name": "athena school of management",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 8:NA | 9:NA | 10:NA | 11:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, NMAT, SNAP, Others, ATMA, KMAT",
    "tution_fees_local_country_student": 700000,
    "program_duration": 2,
    "institute_name": "regional college of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Retail Management, Digital Media"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 276000,
    "program_duration": 2,
    "institute_name": "indian institute of business management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "bihar",
    "city_name": "patna",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "3:NA|4:NA|1:NA|2:NA|11:NA",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CMAT, MAT, CAT, XAT, ATMA",
    "tution_fees_local_country_student": 370000,
    "program_duration": 2,
    "institute_name": "justice k s hegde institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "udupi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 4:NA   | 5:NA   | 11:NA   | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, GRE, Others, ATMA",
    "tution_fees_local_country_student": 824000,
    "program_duration": 2,
    "institute_name": "indus business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|3:NA|5:NA|2:NA|6:NA",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, MAT, CMAT, GMAT, XAT, GRE",
    "tution_fees_local_country_student": 650000,
    "program_duration": 2,
    "institute_name": "amrita school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "kochi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|3:NA|8:NA|1:NA",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "Others, MAT, XAT, CMAT, NMAT, CAT",
    "tution_fees_local_country_student": 1157000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 625000,
    "program_duration": 2,
    "institute_name": "ramachandran international institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "narayana business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "narayana business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:450  | 5:NA  | ",
    "final_placements_domestic_salary_avg": 600000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 469000,
    "program_duration": 2,
    "institute_name": "guru nanak institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 595000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "national institute of management and technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Infrastructure \/ Real Estate"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:60 | 16:NA | ",
    "final_placements_domestic_salary_avg": 592000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, TANCET",
    "tution_fees_local_country_student": 857000,
    "program_duration": 2,
    "institute_name": "thiagarajar school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "madurai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management, Business Analytics"
  },
  {
    "test_cutoff": "2:NA|4:NA|11:NA|1:NA|10:NA",
    "final_placements_domestic_salary_avg": 592000,
    "tests_accepted": "XAT, MAT, ATMA, CAT, Others",
    "tution_fees_local_country_student": 1000000,
    "program_duration": 2,
    "institute_name": "xavier institute of management and entrepreneurship",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 580000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 815000,
    "program_duration": 2,
    "institute_name": "institute of public enterprise",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 580000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 815000,
    "program_duration": 2,
    "institute_name": "institute of public enterprise",
    "program_name": "post graduate diploma in international business",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 580000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others, ATMA",
    "tution_fees_local_country_student": 460000,
    "program_duration": 2,
    "institute_name": "dr. v. n. bedekar institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "thane",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|8:NA|2:NA|3:NA",
    "final_placements_domestic_salary_avg": 578000,
    "tests_accepted": "CAT, MAT, NMAT, XAT, CMAT",
    "tution_fees_local_country_student": 495000,
    "program_duration": 2,
    "institute_name": "chitkara business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "chandigarh region",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 575000,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 650000,
    "program_duration": 2,
    "institute_name": "vanguard business school",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 575000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 353000,
    "program_duration": 2,
    "institute_name": "doon business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 16:NA  | ",
    "final_placements_domestic_salary_avg": 575000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, TANCET",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "school of management srm university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "ramapuram",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 570000,
    "tests_accepted": "CAT, XAT, MAT, CMAT, GMAT",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "birla global university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneshwar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 11:NA  | 18:NA  | ",
    "final_placements_domestic_salary_avg": 570000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA, JMET",
    "tution_fees_local_country_student": 660000,
    "program_duration": 2,
    "institute_name": "institute of technology and science",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 570000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 715000,
    "program_duration": 2,
    "institute_name": "gibs business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 568000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 965000,
    "program_duration": 2,
    "institute_name": "jaipuria institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:55 | 2:55 | 3:NA | 4:55 | 11:NA | ",
    "final_placements_domestic_salary_avg": 560000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 696000,
    "program_duration": 2,
    "institute_name": "institute of rural management",
    "program_name": "post graduate diploma in business management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "1:50  | 3:NA  | 4:NA  | 12:NA  | ",
    "final_placements_domestic_salary_avg": 560000,
    "tests_accepted": "CAT, CMAT, MAT, IBSAT",
    "tution_fees_local_country_student": 745000,
    "program_duration": 2,
    "institute_name": "international institute of business studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 560000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 495000,
    "program_duration": 2,
    "institute_name": "itm business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Digital Media"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 560000,
    "tests_accepted": "CAT, XAT, MAT, ATMA",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "iilm academy of higher learning",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA     | 2:NA     | 3:NA     | 4:NA     | 11:NA     | ",
    "final_placements_domestic_salary_avg": 560000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 720000,
    "program_duration": 2,
    "institute_name": "institute of rural management",
    "program_name": "post graduate diploma in rural management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:73.24 | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 8:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, NMAT, ATMA",
    "tution_fees_local_country_student": 930000,
    "program_duration": 2,
    "institute_name": "institute for technology and management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "navi mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Business Analytics, Digital Media"
  },
  {
    "test_cutoff": "1:NA   | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 317000,
    "program_duration": 2,
    "institute_name": "delhi school of management delhi technological university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:70  | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 562000,
    "program_duration": 2,
    "institute_name": "nit surathkal the school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "mangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 680000,
    "program_duration": 2,
    "institute_name": "atharva institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "delhi school of business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Strategy, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 600000,
    "program_duration": 2,
    "institute_name": "development management institute",
    "program_name": "post graduate program in development management",
    "country_name": "India",
    "state_name": "bihar",
    "city_name": "patna",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 753000,
    "program_duration": 2,
    "institute_name": "tapmi school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 680000,
    "program_duration": 2,
    "institute_name": "institute of insurance and risk management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Business Analytics, Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 675000,
    "program_duration": 2,
    "institute_name": "jagannath international management school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "MAT, CAT, XAT",
    "tution_fees_local_country_student": 620000,
    "program_duration": 2,
    "institute_name": "united world school of business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business, Retail Management, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "jaipuria institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|11:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, MAT, ATMA, CMAT, GMAT",
    "tution_fees_local_country_student": 580000,
    "program_duration": 2,
    "institute_name": "institute of public enterprise",
    "program_name": "post graduate diploma in human resource management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 426000,
    "program_duration": 2,
    "institute_name": "asm's institute of business management and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, CMAT, MAT, MH-CET",
    "tution_fees_local_country_student": 700000,
    "program_duration": 2,
    "institute_name": "christ institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 7:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "kohinoor business school",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA   | 2:NA   | 3:NA   | 16:NA   | ",
    "final_placements_domestic_salary_avg": 550000,
    "tests_accepted": "CAT, XAT, CMAT, TANCET",
    "tution_fees_local_country_student": 650000,
    "program_duration": 2,
    "institute_name": "st. joseph's institute of management",
    "program_name": "post graduate program in global financial markets",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "tiruchirapalli",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 545000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 568000,
    "program_duration": 2,
    "institute_name": "empi business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management, Business Analytics, Media & Communication, Digital Media, E-Commerce"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 543000,
    "tests_accepted": "CAT, XAT, MAT, ATMA",
    "tution_fees_local_country_student": 325000,
    "program_duration": 2,
    "institute_name": "brij mohan institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 6:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 541000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, GRE, Others",
    "tution_fees_local_country_student": 1000000,
    "program_duration": 2,
    "institute_name": "amrita school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management, Business Analytics"
  },
  {
    "test_cutoff": "1:NA|4:NA|3:NA",
    "final_placements_domestic_salary_avg": 540000,
    "tests_accepted": "CAT, MAT, CMAT",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "national power training institute",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "faridabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Power \/ Energy \/ Oil \/ Gas"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 540000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 875000,
    "program_duration": 2,
    "institute_name": "cms business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 534000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "chetana's institute of management and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 5:NA  | 8:NA  | 10:NA  | ",
    "final_placements_domestic_salary_avg": 532000,
    "tests_accepted": "CAT, GMAT, NMAT, Others",
    "tution_fees_local_country_student": 567000,
    "program_duration": 2,
    "institute_name": "icfai ibs dehradun",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA   | 4:NA   | 16:NA   | ",
    "final_placements_domestic_salary_avg": 530000,
    "tests_accepted": "CAT, MAT, TANCET",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "psg institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 530000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "chetana's institute of management and research",
    "program_name": "post graduate diploma in marketing management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 530000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 575000,
    "program_duration": 2,
    "institute_name": "nitte school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 530000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 380000,
    "program_duration": 2,
    "institute_name": "international institute of health management research",
    "program_name": "post graduate diploma in hospital and health management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Information Technology, Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:75   | 2:75   | 3:NA   | 4:90   | 7:NA   | 11:NA   | ",
    "final_placements_domestic_salary_avg": 526000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "institute of management development and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:70 | 2:73 | 3:NA | 4:85 | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 525000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 752000,
    "program_duration": 2,
    "institute_name": "indus business academy",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics, International Business, Retail Management, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 5:NA | 8:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 525000,
    "tests_accepted": "CAT, XAT, MAT, GMAT, NMAT, ATMA",
    "tution_fees_local_country_student": 720600,
    "program_duration": 2,
    "institute_name": "hyderabad business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics, International Business"
  },
  {
    "test_cutoff": "5:NA|1:NA|4:NA",
    "final_placements_domestic_salary_avg": 525000,
    "tests_accepted": "GMAT, CAT, MAT",
    "tution_fees_local_country_student": 220000,
    "program_duration": 2,
    "institute_name": "acn school of business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "aligarh",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Strategy"
  },
  {
    "test_cutoff": "1:50 | 2:50 | 4:NA | 5:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 520000,
    "tests_accepted": "CAT, XAT, MAT, GMAT, Others",
    "tution_fees_local_country_student": 720000,
    "program_duration": 2,
    "institute_name": "gitam institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "andhra pradesh",
    "city_name": "visakhapatnam",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 8:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 520000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, NMAT, Others, ATMA",
    "tution_fees_local_country_student": 495000,
    "program_duration": 2,
    "institute_name": "itm business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "andhra pradesh",
    "city_name": "warangal",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "10:NA|17:NA|4:NA|3:NA|1:NA|5:NA|6:NA",
    "final_placements_domestic_salary_avg": 520000,
    "tests_accepted": "Others, PGCET, MAT, CMAT, CAT, GMAT, GRE",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "pes university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|11:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 520000,
    "tests_accepted": "CAT, XAT, MAT, ATMA, CMAT, GMAT",
    "tution_fees_local_country_student": 580000,
    "program_duration": 2,
    "institute_name": "institute of public enterprise",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Retail Management"
  },
  {
    "test_cutoff": "1:50 | 2:60 | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "scms cochin school of business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA, JMET",
    "tution_fees_local_country_student": 850000,
    "program_duration": 2,
    "institute_name": "thakur institute of management studies and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:60 | 2:75 | 3:75 | 4:75 | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 645000,
    "program_duration": 2,
    "institute_name": "international school of management excellence",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:NA|2:NA|11:NA|5:NA|3:NA",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, ATMA, GMAT, CMAT",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "new delhi institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Business Analytics, International Business, Media & Communication, Digital Media"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 173000,
    "program_duration": 2,
    "institute_name": "army institute of management and technology ",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "lloyd institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, JMET",
    "tution_fees_local_country_student": 195000,
    "program_duration": 2,
    "institute_name": "sri sharada institute of indian management research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 552000,
    "program_duration": 2,
    "institute_name": "institute of health management research",
    "program_name": "post graduate diploma in hospital and health management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Information Technology, Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 11:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, MAT, ATMA, UPSEE",
    "tution_fees_local_country_student": 550000,
    "program_duration": 2,
    "institute_name": "harlal institute of management and technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 640000,
    "program_duration": 2,
    "institute_name": "jaypee business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Strategy, International Business, Media & Communication"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 560000,
    "program_duration": 2,
    "institute_name": "ramachandran international institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Digital Media"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 600000,
    "program_duration": 2,
    "institute_name": "chetana's institute of management and research",
    "program_name": "post graguate diploma in management - retail management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "xavier institute of social service xiss",
    "program_name": "post graduate diploma in marketing management",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "xavier institute of social service xiss",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 660000,
    "program_duration": 2,
    "institute_name": "sri sri university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "cuttack",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET",
    "tution_fees_local_country_student": 670000,
    "program_duration": 2,
    "institute_name": "balaji institute of international business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 500000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 700000,
    "program_duration": 2,
    "institute_name": "mit wpu school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:60",
    "final_placements_domestic_salary_avg": 497000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 812000,
    "program_duration": 2,
    "institute_name": "army institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:50|2:50|4:NA|3:NA|19:NA",
    "final_placements_domestic_salary_avg": 494000,
    "tests_accepted": "CAT, XAT, MAT, CMAT, JMAT",
    "tution_fees_local_country_student": 585000,
    "program_duration": 2,
    "institute_name": "calcutta business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA   | 5:NA   | 8:NA   | 12:NA   | ",
    "final_placements_domestic_salary_avg": 493000,
    "tests_accepted": "CAT, GMAT, NMAT, IBSAT",
    "tution_fees_local_country_student": 567000,
    "program_duration": 2,
    "institute_name": "icfai business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|8:NA|6:NA|5:NA|3:NA|4:NA",
    "final_placements_domestic_salary_avg": 491000,
    "tests_accepted": "CAT, XAT, NMAT, GRE, GMAT, CMAT, MAT",
    "tution_fees_local_country_student": 258000,
    "program_duration": 2,
    "institute_name": "lm thapar school of management thapar university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "Mohali",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Strategy, Power \/ Energy \/ Oil \/ Gas, International Business, Entrepreneurship & Family Business, Sustainability \/ Environment"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 480000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 575000,
    "program_duration": 2,
    "institute_name": "m s ramaiah institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|3:NA|11:NA|2:NA|5:NA",
    "final_placements_domestic_salary_avg": 480000,
    "tests_accepted": "MAT, CAT, CMAT, ATMA, XAT, GMAT",
    "tution_fees_local_country_student": 880000,
    "program_duration": 2,
    "institute_name": "indian institute of health management research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Human Resources, Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 480000,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 575000,
    "program_duration": 2,
    "institute_name": "vanguard business school",
    "program_name": "post graduate program in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 476000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 440000,
    "program_duration": 2,
    "institute_name": "niilm centre for management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 475000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 353000,
    "program_duration": 2,
    "institute_name": "doon business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "International Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA",
    "final_placements_domestic_salary_avg": 470000,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 380000,
    "program_duration": 2,
    "institute_name": "graphic era university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|3:NA|14:NA",
    "final_placements_domestic_salary_avg": 469000,
    "tests_accepted": "CAT, MAT, CMAT, KMAT",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "rajagiri centre for business studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 460000,
    "tests_accepted": "CAT, CMAT, MAT, UPSEE",
    "tution_fees_local_country_student": 210000,
    "program_duration": 2,
    "institute_name": "science and technology entrepreneurs park harcourt butler technological institute",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 460000,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 398000,
    "program_duration": 2,
    "institute_name": "ramachandran international institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA|3:NA",
    "final_placements_domestic_salary_avg": 456000,
    "tests_accepted": "CAT, XAT, MAT, CMAT, ATMA",
    "tution_fees_local_country_student": 459000,
    "program_duration": 2,
    "institute_name": "hindustan institute of technology and science school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|5:NA|3:NA",
    "final_placements_domestic_salary_avg": 455000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, MAT",
    "tution_fees_local_country_student": 998000,
    "program_duration": 2,
    "institute_name": "kirloskar institute of advanced management studies kiams",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "harihar",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:50 | 3:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, CMAT, MH-CET",
    "tution_fees_local_country_student": 780000,
    "program_duration": 2,
    "institute_name": "d. y. patil university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "navi mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Healthcare \/ Hospital \/ Pharma, International Business, Sports, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "vaikunth mehta national institute of cooperative management",
    "program_name": "post graduate diploma in agri business management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "rizvi institute of management studies and research",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 600000,
    "program_duration": 2,
    "institute_name": "bharatiya vidya bhavan's usha and lakshmi mittal institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, MAT, XAT, ATMA, CMAT, GMAT",
    "tution_fees_local_country_student": 1050000,
    "program_duration": 2,
    "institute_name": "entrepreneurship development institute of india",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "gandhinagar",
    "program_duration_text": "2 Years",
    "specialization_name": "Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 7:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 550000,
    "program_duration": 2,
    "institute_name": "kohinoor business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 615000,
    "program_duration": 2,
    "institute_name": "gibs business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others, ATMA",
    "tution_fees_local_country_student": 840000,
    "program_duration": 2,
    "institute_name": "jk lakshmipat university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 600000,
    "program_duration": 2,
    "institute_name": "school of management presidency university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, CMAT, MAT",
    "tution_fees_local_country_student": 72000,
    "program_duration": 2,
    "institute_name": "institute of agri business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "bikaner",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, General Management, Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|11:NA|5:NA",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, MAT, XAT, CMAT, ATMA, GMAT",
    "tution_fees_local_country_student": 925000,
    "program_duration": 2,
    "institute_name": "jaipuria institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | 17:NA | 20:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA, PGCET, IIFT",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "adarsh institute of management and information technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Hospitality \/ Tourism, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 5:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, MAT, GMAT, Others, ATMA",
    "tution_fees_local_country_student": 240000,
    "program_duration": 2,
    "institute_name": "ap goyal shimla university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "himachal pradesh",
    "city_name": "shimla",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|1:NA|5:NA|2:NA|11:NA",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "MAT, CMAT, CAT, GMAT, XAT, ATMA",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "administrative staff college of india",
    "program_name": "post graduate diploma in hospital management",
    "country_name": "India",
    "state_name": "andhra pradesh",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|11:NA",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, MAT, XAT, CMAT, ATMA",
    "tution_fees_local_country_student": 745000,
    "program_duration": 2,
    "institute_name": "jaipuria institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, MAT, ATMA",
    "tution_fees_local_country_student": 320000,
    "program_duration": 2,
    "institute_name": "maharishi arvind institute of science management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 620000,
    "program_duration": 2,
    "institute_name": "united world school of business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "nimt institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Operations \/ SCM \/ Production, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Infrastructure \/ Real Estate"
  },
  {
    "test_cutoff": "1:NA | 3:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, CMAT",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "the icfai university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "himachal pradesh",
    "city_name": "baddi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 5:NA | 8:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, MAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1350000,
    "program_duration": 2,
    "institute_name": "bml munjal university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 375000,
    "program_duration": 2,
    "institute_name": "quantum school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "roorkee",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business, E-Commerce"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 155000,
    "program_duration": 2,
    "institute_name": "neelkanth institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "meerut",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "15:NA|1:NA|2:NA|5:NA|3:NA|11:NA",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "UPSEE, CAT, XAT, GMAT, CMAT, ATMA",
    "tution_fees_local_country_student": 246000,
    "program_duration": 2,
    "institute_name": "accurate institute of advanced management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 965000,
    "program_duration": 2,
    "institute_name": "jaipuria institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Strategy, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | 20:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA, IIFT",
    "tution_fees_local_country_student": 584000,
    "program_duration": 2,
    "institute_name": "krupanidhi school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business, Media & Communication, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, MH-CET",
    "tution_fees_local_country_student": 147000,
    "program_duration": 2,
    "institute_name": "deogiri institute of engineering and management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "aurangabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 10:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, MAT, Others, ATMA, JMET",
    "tution_fees_local_country_student": 550000,
    "program_duration": 2,
    "institute_name": "cmr centre for business studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 14:NA | 17:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, MAT, KMAT, PGCET",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "mvj college of engineering",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, CMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 367000,
    "program_duration": 2,
    "institute_name": "rustomjee business school",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 525000,
    "program_duration": 2,
    "institute_name": "mitcon institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 450000,
    "tests_accepted": "CAT, XAT, MAT, ATMA",
    "tution_fees_local_country_student": 225000,
    "program_duration": 2,
    "institute_name": "harlal institute of management and technology",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Digital Media"
  },
  {
    "test_cutoff": "1:60 | 2:45 | 3:50 | 4:450 | 5:NA  | 11:45 | ",
    "final_placements_domestic_salary_avg": 443000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 715000,
    "program_duration": 2,
    "institute_name": "jagan institute of management studies",
    "program_name": "post graguate diploma in management - retail management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Retail Management, E-Commerce, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 440000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 550000,
    "program_duration": 2,
    "institute_name": "dayananda sagar academy of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, General Management, Sustainability \/ Environment"
  },
  {
    "test_cutoff": "1:NA|4:NA|11:NA|10:NA|10:NA",
    "final_placements_domestic_salary_avg": 425000,
    "tests_accepted": "CAT, MAT, ATMA, Others, Others",
    "tution_fees_local_country_student": 445000,
    "program_duration": 2,
    "institute_name": "eastern institute for integrated learning in management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA|4:NA|7:NA|11:NA",
    "final_placements_domestic_salary_avg": 425000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 425000,
    "program_duration": 2,
    "institute_name": "ramachandran international institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Digital Media"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 420000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "suryadatta institute of business management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 420000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 240000,
    "program_duration": 2,
    "institute_name": "swami rama himalayan university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 418000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 474000,
    "program_duration": 2,
    "institute_name": "birla institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 416000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "vidyalankar institute of technology",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | ",
    "final_placements_domestic_salary_avg": 414000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 112000,
    "program_duration": 2,
    "institute_name": "motilal nehru national institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "allahabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:90 | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 412000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 815000,
    "program_duration": 2,
    "institute_name": "institute of public enterprise",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 410000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 180000,
    "program_duration": 2,
    "institute_name": "institute of media management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 410000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, UPSEE",
    "tution_fees_local_country_student": 122000,
    "program_duration": 2,
    "institute_name": "r. v. northland instiute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:50|4:NA|2:NA|5:NA|3:NA|8:NA",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, MAT, XAT, ATMA, CMAT, GMAT",
    "tution_fees_local_country_student": 700000,
    "program_duration": 2,
    "institute_name": "vignana jyothi institute of management",
    "program_name": "post graduate diploma in business management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management, Business Analytics"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA, JMET",
    "tution_fees_local_country_student": 515000,
    "program_duration": 2,
    "institute_name": "thakur institute of management studies and research",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 430000,
    "program_duration": 2,
    "institute_name": "durgadevi saraf institute of management studies",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 392000,
    "program_duration": 2,
    "institute_name": "bengal institute of business studies",
    "program_name": "post graduate program in business management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources"
  },
  {
    "test_cutoff": "11:NA|1:NA|3:NA|4:NA|2:NA|10:NA",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "ATMA, CAT, CMAT, MAT, XAT, Others",
    "tution_fees_local_country_student": 320000,
    "program_duration": 2,
    "institute_name": "regional college of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneswar",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 3:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, CMAT",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "college of agri business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "pant nagar",
    "program_duration_text": "2 Years",
    "specialization_name": "Healthcare \/ Hospital \/ Pharma, Agri \/ Food \/ Rural Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 9:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, SNAP, ATMA",
    "tution_fees_local_country_student": 488000,
    "program_duration": 2,
    "institute_name": "shri ram murti smarak international business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, CMAT, MAT, UPSEE",
    "tution_fees_local_country_student": 258000,
    "program_duration": 2,
    "institute_name": "mangalmay institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, MAT, ATMA",
    "tution_fees_local_country_student": 270000,
    "program_duration": 2,
    "institute_name": "invertis institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "bareilly",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Retail Management, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, Others, ATMA",
    "tution_fees_local_country_student": 720000,
    "program_duration": 2,
    "institute_name": "itm business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Digital Media"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "international management centre",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 245000,
    "program_duration": 2,
    "institute_name": "center for management technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 143000,
    "program_duration": 2,
    "institute_name": "neelkanth vidhyapeeth",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "meerut",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 320000,
    "program_duration": 2,
    "institute_name": "inmantec business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 11:NA  | 15:NA  | 18:NA  | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, ATMA, UPSEE, JMET",
    "tution_fees_local_country_student": 325000,
    "program_duration": 2,
    "institute_name": "institute of technology and science",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "xavier institute of social service xiss",
    "program_name": "post graduate diploma in rural management",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT",
    "tution_fees_local_country_student": 750000,
    "program_duration": 2,
    "institute_name": "xavier institute of social service xiss",
    "program_name": "post graduate diploma in information technology management",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Information Technology"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | 14:NA | 20:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA, KMAT, IIFT",
    "tution_fees_local_country_student": 420000,
    "program_duration": 2,
    "institute_name": "community institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 240000,
    "program_duration": 2,
    "institute_name": "dayananda sagar business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 325000,
    "program_duration": 2,
    "institute_name": "st.george college of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA|3:NA|14:NA",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 320000,
    "program_duration": 2,
    "institute_name": "bhavans royal institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 172000,
    "program_duration": 2,
    "institute_name": "jodhpur national university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jodhpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, CMAT, MAT, KMAT",
    "tution_fees_local_country_student": 290000,
    "program_duration": 2,
    "institute_name": "monti international institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "malappuram",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 10:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, Others, ATMA, JMET",
    "tution_fees_local_country_student": 262000,
    "program_duration": 2,
    "institute_name": "maratha mandir's babasaheb gawde institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 600000,
    "program_duration": 2,
    "institute_name": "gnvs institute of management",
    "program_name": "post graduate diploma in research and business analytics",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 525000,
    "program_duration": 2,
    "institute_name": "mitcon institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 475000,
    "program_duration": 2,
    "institute_name": "mitcon institute of management",
    "program_name": "post graduate diploma in agri business management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others, ATMA",
    "tution_fees_local_country_student": 290000,
    "program_duration": 2,
    "institute_name": "dr. v. n. bedekar institute of management studies",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "thane",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|3:NA|14:NA",
    "final_placements_domestic_salary_avg": 400000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 340000,
    "program_duration": 2,
    "institute_name": "farook institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "calicut",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources, Digital Media"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 390000,
    "tests_accepted": "CAT, MAT, Others",
    "tution_fees_local_country_student": 100000,
    "program_duration": 2,
    "institute_name": "dev bhoomi institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 388000,
    "tests_accepted": "CAT, MAT, UPSEE",
    "tution_fees_local_country_student": 220000,
    "program_duration": 2,
    "institute_name": "skyline institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 384000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 350000,
    "program_duration": 2,
    "institute_name": "indira institute of business management",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "navi mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 380000,
    "tests_accepted": "CAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "bharati vidyapeeth's institute of management studies and research",
    "program_name": "post graduate diploma in business management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "navi mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 380000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 530000,
    "program_duration": 2,
    "institute_name": "accman institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 375000,
    "tests_accepted": "CAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "institute of productivity and management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|11:NA|2:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 374000,
    "tests_accepted": "MAT, CAT, ATMA, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 475000,
    "program_duration": 2,
    "institute_name": "siva sivani institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Retail Management"
  },
  {
    "test_cutoff": "1:75 | 2:70 | 3:70 | 4:480 | 5:NA | 11:60 | ",
    "final_placements_domestic_salary_avg": 372000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 715000,
    "program_duration": 2,
    "institute_name": "jagan institute of management studies",
    "program_name": "post graduate diploma in international business",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 10:NA | 11:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 372000,
    "tests_accepted": "CAT, XAT, MAT, Others, ATMA, KMAT",
    "tution_fees_local_country_student": 349000,
    "program_duration": 2,
    "institute_name": "international academy of management and entrepreneurship",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, International Business, Retail Management, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 7:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 370000,
    "tests_accepted": "CAT, MAT, MH-CET, Others",
    "tution_fees_local_country_student": 260000,
    "program_duration": 2,
    "institute_name": "sharadchandra pawar institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 370000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 260000,
    "program_duration": 2,
    "institute_name": "institute of management and computer studies",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "thane",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "3:NA|1:50|4:NA|11:NA|2:NA|9:NA|5:NA",
    "final_placements_domestic_salary_avg": 360000,
    "tests_accepted": "CMAT, CAT, MAT, ATMA, XAT, SNAP, GMAT",
    "tution_fees_local_country_student": 385000,
    "program_duration": 2,
    "institute_name": "icbm school of business excellence",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Business Analytics, Agri \/ Food \/ Rural Business, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 360000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 280000,
    "program_duration": 2,
    "institute_name": "jain institute of management and entrepreneurship",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "jamshedpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 360000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 320000,
    "program_duration": 2,
    "institute_name": "marian international institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "iduki",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 360000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 250000,
    "program_duration": 2,
    "institute_name": "sb college of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:60 | 2:60 | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "aims institutes",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|5:NA|2:NA|11:NA|10:NA",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, MAT, GMAT, XAT, ATMA, Others",
    "tution_fees_local_country_student": 455000,
    "program_duration": 2,
    "institute_name": "iikm business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Hospitality \/ Tourism"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, MAT, XAT",
    "tution_fees_local_country_student": 106000,
    "program_duration": 2,
    "institute_name": "govindram seksaria institute of management and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, CMAT, MAT",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "arya institute of engineering technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, Others, ATMA",
    "tution_fees_local_country_student": 217000,
    "program_duration": 2,
    "institute_name": "nimt institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 4:NA  | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "mount carmel institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|5:NA|17:NA|3:NA|14:NA|11:NA",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, MAT, XAT, GMAT, PGCET, CMAT, KMAT, ATMA",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "institute of business management and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "hubli",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 208000,
    "program_duration": 2,
    "institute_name": "babu banarasi das national institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, MAT, UPSEE",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "b.n. college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|15:NA",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, MAT, XAT, UPSEE",
    "tution_fees_local_country_student": 303000,
    "program_duration": 2,
    "institute_name": "gla institute of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "mathura",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Business Analytics, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 850000,
    "program_duration": 2,
    "institute_name": "durgadevi saraf institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Media & Communication"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA|4:NA|15:NA",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, UPSEE",
    "tution_fees_local_country_student": 110000,
    "program_duration": 2,
    "institute_name": "neelam college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "agra",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 10:NA | 14:NA | 17:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, Others, KMAT, PGCET",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "administrative management college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 14:NA | 17:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, KMAT, PGCET",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "atria school of management and entrepreneurship",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 11:NA | 14:NA | 17:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, CMAT, MAT, ATMA, KMAT, PGCET",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "r.v.institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 410000,
    "program_duration": 2,
    "institute_name": "mams marian academy of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "scms school of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "apex institute of management and science college",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Digital Media"
  },
  {
    "test_cutoff": "1:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 136000,
    "program_duration": 2,
    "institute_name": "international school of informatics and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 233000,
    "program_duration": 2,
    "institute_name": "sheila raheja school of business management and research",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 350000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 166000,
    "program_duration": 2,
    "institute_name": "marathwada mitra mandal's college of engineering",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|11:NA|5:NA|10:NA",
    "final_placements_domestic_salary_avg": 348000,
    "tests_accepted": "CAT, XAT, MAT, ATMA, GMAT, Others",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "sanghvi institute of management and science",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 14:NA | 17:NA | ",
    "final_placements_domestic_salary_avg": 345000,
    "tests_accepted": "CAT, XAT, MAT, KMAT, PGCET",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "indian academy school of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "3:NA|14:NA|1:NA|17:NA",
    "final_placements_domestic_salary_avg": 340000,
    "tests_accepted": "CMAT, KMAT, CAT",
    "tution_fees_local_country_student": 320000,
    "program_duration": 2,
    "institute_name": "kls gogte institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "belgaum",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 340000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 374000,
    "program_duration": 2,
    "institute_name": "saintgits institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "kottayam",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 340000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 240000,
    "program_duration": 2,
    "institute_name": "international school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "bihar",
    "city_name": "patna",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 330000,
    "tests_accepted": "CAT, CMAT, MAT, Others",
    "tution_fees_local_country_student": 148000,
    "program_duration": 2,
    "institute_name": "parul institute of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "vadodara",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|18:NA|11:NA|10:NA|10:NA",
    "final_placements_domestic_salary_avg": 326000,
    "tests_accepted": "CAT, MAT, XAT, JMET, ATMA, Others, Others",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "global business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "hubli",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 325000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 570000,
    "program_duration": 2,
    "institute_name": "national school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 325000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 675000,
    "program_duration": 2,
    "institute_name": "jagannath international management school",
    "program_name": "post graduate diploma in international business",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 325000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 268000,
    "program_duration": 2,
    "institute_name": "nimbus academy of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 325000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 180000,
    "program_duration": 2,
    "institute_name": "center for management technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 325000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 150000,
    "program_duration": 2,
    "institute_name": "innocent hearts school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "jalandhar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 325000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 141000,
    "program_duration": 2,
    "institute_name": "lachoo memorial college of science and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jodhpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 325000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 280000,
    "program_duration": 2,
    "institute_name": "school of management and business studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "kottayam",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 325000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 237000,
    "program_duration": 2,
    "institute_name": "shri ramdeobaba college of engineering and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 324000,
    "tests_accepted": "CAT, MAT",
    "tution_fees_local_country_student": 144000,
    "program_duration": 2,
    "institute_name": "tula's institute the engineering and management college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 321000,
    "tests_accepted": "CAT, MAT, Others",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "suresh gyan vihar school of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 4:NA  | 10:NA  | ",
    "final_placements_domestic_salary_avg": 320000,
    "tests_accepted": "CAT, XAT, MAT, Others",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "school of business shobhit university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "meerut",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 320000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA, KMAT",
    "tution_fees_local_country_student": 260000,
    "program_duration": 2,
    "institute_name": "ahalia school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "palakkad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 320000,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 250000,
    "program_duration": 2,
    "institute_name": "jecrc university school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 11:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 320000,
    "tests_accepted": "CAT, CMAT, MAT, ATMA, UPSEE",
    "tution_fees_local_country_student": 310000,
    "program_duration": 2,
    "institute_name": "hierank business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 320000,
    "tests_accepted": "CAT, Others",
    "tution_fees_local_country_student": 208000,
    "program_duration": 2,
    "institute_name": "hmr institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 8:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 320000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, NMAT, ATMA",
    "tution_fees_local_country_student": 560000,
    "program_duration": 2,
    "institute_name": "bse institute limited",
    "program_name": "post graduate program in global financial markets",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 320000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 158000,
    "program_duration": 2,
    "institute_name": "matrix school of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 320000,
    "tests_accepted": "CAT, XAT, CMAT, Others",
    "tution_fees_local_country_student": 131000,
    "program_duration": 2,
    "institute_name": "nilaai institutions of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Sustainability \/ Environment"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 310000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "apollo institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | ",
    "final_placements_domestic_salary_avg": 310000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 122000,
    "program_duration": 2,
    "institute_name": "guru jambheshwar university of science and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "hissar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 309000,
    "tests_accepted": "CAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 630000,
    "program_duration": 2,
    "institute_name": "dr. gaur hari singhania institute of management and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, MAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 392000,
    "program_duration": 2,
    "institute_name": "royal school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "assam",
    "city_name": "guwahati",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 660000,
    "program_duration": 2,
    "institute_name": "sri sri university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "cuttack",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Agri \/ Food \/ Rural Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 14:NA | 17:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, KMAT, PGCET",
    "tution_fees_local_country_student": 106000,
    "program_duration": 2,
    "institute_name": "b.n.m institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|14:NA|1:NA|2\u00a0:NA",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "MAT, CMAT, KMAT, CAT, XAT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "centurion university of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneshwar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, MAT",
    "tution_fees_local_country_student": 180000,
    "program_duration": 2,
    "institute_name": "rakshpal bahadur management institute",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, MAT",
    "tution_fees_local_country_student": 220000,
    "program_duration": 2,
    "institute_name": "sadanam institute of commerce and management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "palakkad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA, JMET",
    "tution_fees_local_country_student": 90000,
    "program_duration": 2,
    "institute_name": "rajarshi shahu institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "aurangabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 14:NA | 17:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, CMAT, MAT, KMAT, PGCET",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "the oxford college of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 350000,
    "program_duration": 2,
    "institute_name": "indo asian academy management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 240000,
    "program_duration": 2,
    "institute_name": "guru gram business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 146000,
    "program_duration": 2,
    "institute_name": "khandelwal college of management science and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "bareilly",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA, UPSEE",
    "tution_fees_local_country_student": 296000,
    "program_duration": 2,
    "institute_name": "apeejay institute of technology school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, MAT, UPSEE",
    "tution_fees_local_country_student": 190000,
    "program_duration": 2,
    "institute_name": "aligarh college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "aligarh",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "department of management science",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "aurangabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 142000,
    "program_duration": 2,
    "institute_name": "btl institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 14:NA | 17:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, MAT, KMAT, PGCET",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "don bosco institute of management studies and computer applications",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "14:NA|3:NA|4:NA|1:NA",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "KMAT, CMAT, MAT, CAT",
    "tution_fees_local_country_student": 210000,
    "program_duration": 2,
    "institute_name": "rjs institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 396000,
    "program_duration": 2,
    "institute_name": "sjes college of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 432000,
    "program_duration": 2,
    "institute_name": "fisat business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, CMAT, MAT",
    "tution_fees_local_country_student": 182000,
    "program_duration": 2,
    "institute_name": "shri guru ram rai institute of technology and science",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "noida institute of engineering and technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, CMAT, MAT",
    "tution_fees_local_country_student": 190000,
    "program_duration": 2,
    "institute_name": "patronage institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 110000,
    "program_duration": 2,
    "institute_name": "chandra mauli institute of management sciences and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "gorakhpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, CMAT, MAT",
    "tution_fees_local_country_student": 121000,
    "program_duration": 2,
    "institute_name": "rajasthan institute of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 5:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, KMAT",
    "tution_fees_local_country_student": 270000,
    "program_duration": 2,
    "institute_name": "mangalam management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "kottayam",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 183000,
    "program_duration": 2,
    "institute_name": "ar institute of management and technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "meerut",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 256000,
    "program_duration": 2,
    "institute_name": "aruna manharlal shah institute of management and research",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others, ATMA",
    "tution_fees_local_country_student": 2300000,
    "program_duration": 2,
    "institute_name": "gnvs institute of management",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 264000,
    "program_duration": 2,
    "institute_name": "sir. m. visvesvaraya institute of management studies and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "rajiv gandhi business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 140000,
    "program_duration": 2,
    "institute_name": "navsahyadri group of institutes",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA, JMET",
    "tution_fees_local_country_student": 175000,
    "program_duration": 2,
    "institute_name": "pratibha institute of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 158000,
    "program_duration": 2,
    "institute_name": "s. b. patil institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 5:NA  | 10:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 300000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, Others, ATMA",
    "tution_fees_local_country_student": 600000,
    "program_duration": 2,
    "institute_name": "sai balaji international institute of management sciences",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 295000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "prince institute of innovative technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|8:NA|3:NA|2:NA|10:NA",
    "final_placements_domestic_salary_avg": 293000,
    "tests_accepted": "CAT, MAT, NMAT, CMAT, XAT, Others",
    "tution_fees_local_country_student": 238000,
    "program_duration": 2,
    "institute_name": "college of business management economics and commerce mody university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "sikar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Business Analytics, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 290000,
    "tests_accepted": "CAT, XAT, MAT, ATMA",
    "tution_fees_local_country_student": 325000,
    "program_duration": 2,
    "institute_name": "shiva institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Retail Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 290000,
    "tests_accepted": "CAT, XAT, MAT, ATMA",
    "tution_fees_local_country_student": 161000,
    "program_duration": 2,
    "institute_name": "beehive college of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 3:NA  | 4:NA  | 11:NA  | 15:NA  | ",
    "final_placements_domestic_salary_avg": 290000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA, UPSEE",
    "tution_fees_local_country_student": 94000,
    "program_duration": 2,
    "institute_name": "ar institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "meerut",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 280000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 126000,
    "program_duration": 2,
    "institute_name": "aima centre for management education",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 280000,
    "tests_accepted": "CAT, CMAT, MAT",
    "tution_fees_local_country_student": 550000,
    "program_duration": 2,
    "institute_name": "jagan institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 280000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 127000,
    "program_duration": 2,
    "institute_name": "college of engineering rural technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "meerut",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 280000,
    "tests_accepted": "CAT, MH-CET",
    "tution_fees_local_country_student": 128000,
    "program_duration": 2,
    "institute_name": "international centre of excellence in engineering and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "aurangabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 280000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 150000,
    "program_duration": 2,
    "institute_name": "noida institute of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 280000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 171000,
    "program_duration": 2,
    "institute_name": "sarvottam institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 275000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 130000,
    "program_duration": 2,
    "institute_name": "dayalbagh educational institutedepartment of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "agra",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 275000,
    "tests_accepted": "CAT, CMAT, MAT, KMAT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "city college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 275000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "toc h institute of science and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 270000,
    "tests_accepted": "CAT, CMAT, MAT, UPSEE",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "al barkaat institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "aligarh",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 260000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 150000,
    "program_duration": 2,
    "institute_name": "bm college of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | 17:NA | 20:NA | ",
    "final_placements_domestic_salary_avg": 260000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA, PGCET, IIFT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "oxbridge business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 260000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 105000,
    "program_duration": 2,
    "institute_name": "institute of cooperative management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 260000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 226000,
    "program_duration": 2,
    "institute_name": "tirpude institute of management education",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 5:NA | 10:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 260000,
    "tests_accepted": "CAT, CMAT, MAT, GMAT, Others, JMET",
    "tution_fees_local_country_student": 172000,
    "program_duration": 2,
    "institute_name": "tulsiramji gaikwad patil college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 284000,
    "program_duration": 2,
    "institute_name": "sinhgad institute of business administration and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 80000,
    "program_duration": 2,
    "institute_name": "institute of management studies ranchi university ",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "10:NA|3:NA|1:NA",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "Others, CMAT, CAT",
    "tution_fees_local_country_student": 121000,
    "program_duration": 2,
    "institute_name": "sobhasaria group of institutions sikar",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "sikar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, XAT, MAT, CMAT, GMAT",
    "tution_fees_local_country_student": 445000,
    "program_duration": 2,
    "institute_name": "itm university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "raipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 15:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, MAT, UPSEE",
    "tution_fees_local_country_student": 92000,
    "program_duration": 2,
    "institute_name": "anand engineering college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "agra",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 350000,
    "program_duration": 2,
    "institute_name": "indian institute of plantation management",
    "program_name": "post graduate diploma in agri business management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|11:NA|2:NA|3:NA",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, MAT, ATMA, XAT, CMAT",
    "tution_fees_local_country_student": 184000,
    "program_duration": 2,
    "institute_name": "girijananda chowdhury institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "assam",
    "city_name": "guwahati",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 110000,
    "program_duration": 2,
    "institute_name": "gd memorial college of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jodhpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 136000,
    "program_duration": 2,
    "institute_name": "dr.virendra swarup institute of computer studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA, JMET",
    "tution_fees_local_country_student": 121000,
    "program_duration": 2,
    "institute_name": "maratha mandir's babasaheb gawde institute of management studies",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 156000,
    "program_duration": 2,
    "institute_name": "pimpri chinchwad college of engineering",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA, JMET",
    "tution_fees_local_country_student": 170000,
    "program_duration": 2,
    "institute_name": "pravara centre for management research and development",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 164000,
    "program_duration": 2,
    "institute_name": "rjspm's institute of computer and management research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 152000,
    "program_duration": 2,
    "institute_name": "s. r. luthra institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "surat",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 250000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 156000,
    "program_duration": 2,
    "institute_name": "sas institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "thane",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Strategy"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 240000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, KMAT",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "marthoma college of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "perumbavoor",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 240000,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 194000,
    "program_duration": 2,
    "institute_name": "greater noida institute of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 240000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 179000,
    "program_duration": 2,
    "institute_name": "viva institute of management and research",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "thane",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 230000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 164000,
    "program_duration": 2,
    "institute_name": "wainganga college of engineering and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Power \/ Energy \/ Oil \/ Gas, Agri \/ Food \/ Rural Business, International Business, Sustainability \/ Environment"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 230000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, Others, ATMA",
    "tution_fees_local_country_student": 136000,
    "program_duration": 2,
    "institute_name": "progressive education society's institute of management and career development",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 225000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 144000,
    "program_duration": 2,
    "institute_name": "girideepam institute of advanced learning",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "kottayam",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 223000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 179000,
    "program_duration": 2,
    "institute_name": "sadhu vaswani institute of management studies for girls",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | ",
    "final_placements_domestic_salary_avg": 220000,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "mjrp college of corporate management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 220000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 108000,
    "program_duration": 2,
    "institute_name": "phonics school of business administration",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "roorkee",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 220000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others, ATMA",
    "tution_fees_local_country_student": 211000,
    "program_duration": 2,
    "institute_name": "dr. sarvapalli radhakrishnan college of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Power \/ Energy \/ Oil \/ Gas, International Business"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 5:NA | 7:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 210000,
    "tests_accepted": "CAT, MAT, GMAT, MH-CET, ATMA, JMET",
    "tution_fees_local_country_student": 142000,
    "program_duration": 2,
    "institute_name": "karmaveer dadasaheb kannamwar engineering college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 210000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 260000,
    "program_duration": 2,
    "institute_name": "asma institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|3:NA",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, MAT, CMAT",
    "tution_fees_local_country_student": 396000,
    "program_duration": 2,
    "institute_name": "school of management sciences",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "varanasi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|5:NA",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, MAT, XAT, GMAT",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "veltech dr rr and dr sr university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 4:NA  | 11:NA  | 14:NA  | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, MAT, ATMA, KMAT",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "intech institute of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, Others, ATMA",
    "tution_fees_local_country_student": 191000,
    "program_duration": 2,
    "institute_name": "dr. ambedkar institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 100000,
    "program_duration": 2,
    "institute_name": "sree narayana guru institute of science and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 121000,
    "program_duration": 2,
    "institute_name": "apex institute of management and science college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 110000,
    "program_duration": 2,
    "institute_name": "compucom institute of information technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 168000,
    "program_duration": 2,
    "institute_name": "green heaven institute of management and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 198000,
    "program_duration": 2,
    "institute_name": "smt. radhikabai pandav college of engineering",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others, ATMA",
    "tution_fees_local_country_student": 174000,
    "program_duration": 2,
    "institute_name": "anekant institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "audyogik shikshan mandal institute of professional studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 186000,
    "program_duration": 2,
    "institute_name": "camp education society's rasiklal m. dhariwal institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, Others, ATMA",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "modern institute of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 200000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 146000,
    "program_duration": 2,
    "institute_name": "sankalp business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 190000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 110000,
    "program_duration": 2,
    "institute_name": "biff and bright college of technical education",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 4:NA | 5:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 190000,
    "tests_accepted": "CAT, MAT, GMAT, MH-CET",
    "tution_fees_local_country_student": 152000,
    "program_duration": 2,
    "institute_name": "arihant institute of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 180000,
    "tests_accepted": "MAT, CAT, XAT",
    "tution_fees_local_country_student": 220000,
    "program_duration": 2,
    "institute_name": "jagran institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 7:NA | 10:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 180000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, Others, ATMA",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "poona institute of management sciences and entrepreneurship",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 150000,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 70000,
    "program_duration": 2,
    "institute_name": "shri rgp gujarati professional institute",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 150000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 220000,
    "program_duration": 2,
    "institute_name": "allana institute of management sciences",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|3:NA",
    "final_placements_domestic_salary_avg": 144000,
    "tests_accepted": "CAT, XAT, MAT, CMAT",
    "tution_fees_local_country_student": 110000,
    "program_duration": 2,
    "institute_name": "ambedkar institute of management studies",
    "program_name": "post graduate diploma in business management",
    "country_name": "India",
    "state_name": "andhra pradesh",
    "city_name": "visakhapatnam",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources, Retail Management"
  },
  {
    "test_cutoff": "1:50  | 4:NA  | ",
    "final_placements_domestic_salary_avg": 100000,
    "tests_accepted": "CAT, MAT",
    "tution_fees_local_country_student": 45000,
    "program_duration": 2,
    "institute_name": "the business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "jammu and kashmir",
    "city_name": "Jammu",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 10:NA | 11:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 100000,
    "tests_accepted": "CAT, XAT, Others, ATMA, KMAT",
    "tution_fees_local_country_student": 25550,
    "program_duration": 2,
    "institute_name": "institute of business management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 40000,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 196000,
    "program_duration": 2,
    "institute_name": "s b jain institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:80    | 2:NA    | 5:650    | 6:320    | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, GMAT, GRE",
    "tution_fees_local_country_student": 650000,
    "program_duration": 1,
    "institute_name": "s.p. jain institute of management and research",
    "program_name": "global management program",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "1 Year",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|3:NA|8:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, XAT, CMAT, NMAT, CAT",
    "tution_fees_local_country_student": 1157000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Power \/ Energy \/ Oil \/ Gas"
  },
  {
    "test_cutoff": "7:NA|1:NA|2:NA|4:NA|11:NA|18:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MH-CET, CAT, XAT, MAT, ATMA, JMET",
    "tution_fees_local_country_student": 310000,
    "program_duration": 2,
    "institute_name": "maeer's mit school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 596000,
    "program_duration": 2,
    "institute_name": "asian school of business management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneswar",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:50|4:NA|2:NA|18:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, JMAT, XAT, CMAT",
    "tution_fees_local_country_student": 710000,
    "program_duration": 2,
    "institute_name": "globsyn business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "3:NA|1:NA|2:NA|4:NA|11:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, XAT, MAT, ATMA, GMAT",
    "tution_fees_local_country_student": 670000,
    "program_duration": 2,
    "institute_name": "indira school of business studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA  | 2:NA  | 4:NA  | 8:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, NMAT, ATMA",
    "tution_fees_local_country_student": 690000,
    "program_duration": 2,
    "institute_name": "institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|5:NA|8:NA|2:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, GMAT, NMAT, XAT, Others",
    "tution_fees_local_country_student": 1000000,
    "program_duration": 2,
    "institute_name": "school of management and entrepreneurship shiv nadar university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT",
    "tution_fees_local_country_student": 128000,
    "program_duration": 2,
    "institute_name": "department of business administration tezpur university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "assam",
    "city_name": "tezpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:70",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 100000,
    "program_duration": 2,
    "institute_name": "jawaharlal nehru school of management studies assam university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "assam",
    "city_name": "silchar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT, Others",
    "tution_fees_local_country_student": 460000,
    "program_duration": 2,
    "institute_name": "school of business kaziranga university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "assam",
    "city_name": "jorhat",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|3:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, CMAT, XAT",
    "tution_fees_local_country_student": 566000,
    "program_duration": 2,
    "institute_name": "nit rourkela school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "Rourkela",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|3:NA|11:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, CMAT, ATMA, Others",
    "tution_fees_local_country_student": 645000,
    "program_duration": 2,
    "institute_name": "pune institute of business management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, CMAT, GMAT",
    "tution_fees_local_country_student": 810000,
    "program_duration": 2,
    "institute_name": "iilm graduate school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA|4:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others",
    "tution_fees_local_country_student": 360000,
    "program_duration": 2,
    "institute_name": "heritage business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "2:60|4:NA|1:60|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "XAT, MAT, CAT, CMAT",
    "tution_fees_local_country_student": 510000,
    "program_duration": 2,
    "institute_name": "institute of management and information science",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneswar",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|10:NA|10:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, Others, Others, Others",
    "tution_fees_local_country_student": 295000,
    "program_duration": 2,
    "institute_name": "bharatiya vidya bhavan\u00e2",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneshwar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Retail Management, Media & Communication"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT, Others",
    "tution_fees_local_country_student": 350000,
    "program_duration": 2,
    "institute_name": "jagran institute of communication and management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "bhopal",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Media & Communication"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT",
    "tution_fees_local_country_student": 680000,
    "program_duration": 2,
    "institute_name": "jre school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "5:NA|1:NA|2:NA|6:NA|3:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "GMAT, CAT, XAT, GRE, CMAT, CMAT",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "myra school of business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "mysore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Strategy, Business Analytics"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 7:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, MH-CET",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "national institute of securities markets",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "navi mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance"
  },
  {
    "test_cutoff": "1:NA|4:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, CMAT",
    "tution_fees_local_country_student": 242000,
    "program_duration": 2,
    "institute_name": "atal bihari vajpayee indian institute of information technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "gwalior",
    "program_duration_text": "2 Years",
    "specialization_name": "Information Technology"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT, ATMA",
    "tution_fees_local_country_student": 695000,
    "program_duration": 2,
    "institute_name": "jaipuria institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others",
    "tution_fees_local_country_student": 725000,
    "program_duration": 2,
    "institute_name": "imm fostiima business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA     | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 1616000,
    "program_duration": 2,
    "institute_name": "indian institute of management lucknow",
    "program_name": "post graduate program in sustainable management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Sustainability \/ Environment"
  },
  {
    "test_cutoff": "10:NA|2:NA|10:NA|1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, XAT, Others, CAT, MAT",
    "tution_fees_local_country_student": 490000,
    "program_duration": 2,
    "institute_name": "inmantec business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|19:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, JMAT",
    "tution_fees_local_country_student": 224000,
    "program_duration": 2,
    "institute_name": "abs academy of science technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "durgapur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|1:NA|10:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, Others, XAT",
    "tution_fees_local_country_student": 240000,
    "program_duration": 2,
    "institute_name": "maharishi institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA|4:NA|11:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, ATMA, CMAT, GMAT",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "indian institute of plantation management",
    "program_name": "post graduate diploma in agri business management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA|3:NA|5:NA|20:NA|2:NA|4:NA|11:NA|14:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, GMAT, IIFT, XAT, MAT, ATMA, KMAT",
    "tution_fees_local_country_student": 420000,
    "program_duration": 2,
    "institute_name": "community institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Agri \/ Food \/ Rural Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, ATMA, Others",
    "tution_fees_local_country_student": 115000,
    "program_duration": 2,
    "institute_name": "prism school of business and entrepreneurship",
    "program_name": "post graduate diploma in healthcare and hospital management",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "bhilai",
    "program_duration_text": "2 Years",
    "specialization_name": "Information Technology, Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "4:NA|1:NA|2:NA|3:NA|11:NA|18:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, XAT, CMAT, ATMA, JMET, Others",
    "tution_fees_local_country_student": 485000,
    "program_duration": 2,
    "institute_name": "institute of advanced management and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "3:NA|1:NA|4:NA|2:NA|18:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, MAT, XAT, JMET, ATMA",
    "tution_fees_local_country_student": 127000,
    "program_duration": 2,
    "institute_name": "rungta college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "bhilai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT",
    "tution_fees_local_country_student": 327000,
    "program_duration": 2,
    "institute_name": "iimt school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, XAT, CAT",
    "tution_fees_local_country_student": 500000,
    "program_duration": 2,
    "institute_name": "school of business studies sharda university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Business Analytics, Healthcare \/ Hospital \/ Pharma, International Business"
  },
  {
    "test_cutoff": "3:NA|1:NA|4:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, MAT, XAT",
    "tution_fees_local_country_student": 116000,
    "program_duration": 2,
    "institute_name": "aashlar business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "mathura",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, GMAT",
    "tution_fees_local_country_student": 1500000,
    "program_duration": 1,
    "institute_name": "ntpc school of business",
    "program_name": "executive pgdm",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "1 Year",
    "specialization_name": "General Management, Power \/ Energy \/ Oil \/ Gas"
  },
  {
    "test_cutoff": "10:NA|3:NA|10:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, CMAT, Others, CAT",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "medi caps university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "3:NA|4:NA|2:NA|11:NA|1:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, MAT, XAT, ATMA, CAT, Others",
    "tution_fees_local_country_student": 290000,
    "program_duration": 2,
    "institute_name": "itm school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "gwalior",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "10:NA|1:NA|4:NA|2:NA|11:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, CAT, MAT, XAT, ATMA, CMAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "niis institute of business administration",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "bhubaneshwar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|3:NA|2:NA|11:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, XAT, ATMA, MAT",
    "tution_fees_local_country_student": 102000,
    "program_duration": 2,
    "institute_name": "aima centre for management education",
    "program_name": "post graduate diploma in information technology management",
    "country_name": "India",
    "state_name": "delhi",
    "city_name": "new delhi",
    "program_duration_text": "2 Years",
    "specialization_name": "Information Technology, Human Resources, Business Analytics, E-Commerce"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|10:NA|8:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT, Others, NMAT",
    "tution_fees_local_country_student": 377000,
    "program_duration": 2,
    "institute_name": "school of management services ansal university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, GMAT",
    "tution_fees_local_country_student": 158000,
    "program_duration": 2,
    "institute_name": "hrit group of institutions",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|3:NA|2:NA|11:NA|18:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, CMAT, XAT, ATMA, JMET",
    "tution_fees_local_country_student": 470000,
    "program_duration": 2,
    "institute_name": "iilm academy of higher learning",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|5:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT, GMAT, ATMA",
    "tution_fees_local_country_student": 360000,
    "program_duration": 2,
    "institute_name": "international institute for special education",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT",
    "tution_fees_local_country_student": 426000,
    "program_duration": 2,
    "institute_name": "techno institute of management sciences",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "3:NA|4:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, MAT, CAT",
    "tution_fees_local_country_student": 360000,
    "program_duration": 2,
    "institute_name": "rajadhani business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "thiruvananthapuram",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "4:NA|1:NA|10:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, Others, CMAT",
    "tution_fees_local_country_student": 130000,
    "program_duration": 2,
    "institute_name": "parul institute of management and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "vadodara",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "4:NA|10:NA|1:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, Others, CAT, CMAT",
    "tution_fees_local_country_student": 250000,
    "program_duration": 2,
    "institute_name": "parul institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "vadodara",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|10:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, Others, CMAT",
    "tution_fees_local_country_student": 136000,
    "program_duration": 2,
    "institute_name": "parul institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "vadodara",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|3:NA|2:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, CMAT, XAT, ATMA",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "raipur institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "raipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA|4:NA|11:NA|2:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, ATMA, XAT, CMAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "ritee business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "raipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Agri \/ Food \/ Rural Business, Retail Management"
  },
  {
    "test_cutoff": "3:NA|1:NA|2:NA|5:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, XAT, GMAT, MAT",
    "tution_fees_local_country_student": 445000,
    "program_duration": 2,
    "institute_name": "st kabir institute of professional studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, Others",
    "tution_fees_local_country_student": 320000,
    "program_duration": 2,
    "institute_name": "nerim group of institutions",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "assam",
    "city_name": "guwahati",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT",
    "tution_fees_local_country_student": 204000,
    "program_duration": 2,
    "institute_name": "nerim group of institutions",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "assam",
    "city_name": "guwahati",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|5:NA|4:NA|10:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, GMAT, MAT, Others, Others",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "isttm technology business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "Telangana",
    "city_name": "hyderabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Business Analytics, Digital Media, Infrastructure \/ Real Estate"
  },
  {
    "test_cutoff": "1:NA|3:NA|4:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, MAT, Others",
    "tution_fees_local_country_student": 313000,
    "program_duration": 2,
    "institute_name": "lingaya's university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "faridabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA|5:NA|4.:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, GMAT, MAT, ",
    "tution_fees_local_country_student": 192000,
    "program_duration": 2,
    "institute_name": "national institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "3:NA|1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, MAT",
    "tution_fees_local_country_student": 174000,
    "program_duration": 2,
    "institute_name": "ambalika institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|1:NA|3:NA|2:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, CMAT, XAT, Others",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "jaipur national university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "4:NA|1:NA|3:NA|2:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, CMAT, XAT, Others",
    "tution_fees_local_country_student": 340000,
    "program_duration": 2,
    "institute_name": "jaipur national university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, Others",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "gandhi institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "gunupur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "4:NA|1:NA|3:NA|2:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, CMAT, XAT, GMAT",
    "tution_fees_local_country_student": 100000,
    "program_duration": 2,
    "institute_name": "indian institute of engineering science and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "howrah",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "south point institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "sonepat",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, General Management, Healthcare \/ Hospital \/ Pharma, International Business, E-Commerce, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|11:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, ATMA, CMAT",
    "tution_fees_local_country_student": 80000,
    "program_duration": 2,
    "institute_name": "faculty of management studies doranda college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "jharkhand",
    "city_name": "ranchi",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, ATMA",
    "tution_fees_local_country_student": 250000,
    "program_duration": 2,
    "institute_name": "maharishi arvind institute of science management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 140000,
    "program_duration": 2,
    "institute_name": "mjrp college of corporate management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Retail Management"
  },
  {
    "test_cutoff": "1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "mjrp college of corporate management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "3:NA|1:NA|4:NA|2:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, MAT, XAT, GMAT",
    "tution_fees_local_country_student": 306000,
    "program_duration": 2,
    "institute_name": "don bosco institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "assam",
    "city_name": "guwahati",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources, General Management"
  },
  {
    "test_cutoff": "3:NA|4:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, MAT, CAT, XAT",
    "tution_fees_local_country_student": 35000,
    "program_duration": 2,
    "institute_name": "j.d. women's college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "bihar",
    "city_name": "patna",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|17:NA|14:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, PGCET, KMAT",
    "tution_fees_local_country_student": 250000,
    "program_duration": 2,
    "institute_name": "gupta institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 850000,
    "program_duration": 2,
    "institute_name": "mats institute of management and entrepreneurship",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|5:NA|17:NA|3:NA|14:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, GMAT, PGCET, CMAT, KMAT, ATMA",
    "tution_fees_local_country_student": 110000,
    "program_duration": 2,
    "institute_name": "institute of excellence in management science iems b school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "hubli",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA|3:NA|2:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, XAT, MAT",
    "tution_fees_local_country_student": 100000,
    "program_duration": 2,
    "institute_name": "central college of engineering and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "raipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|11:NA|18:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, ATMA, JMET, XAT",
    "tution_fees_local_country_student": 180000,
    "program_duration": 2,
    "institute_name": "shivalik institute of management and education research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "durg",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Agri \/ Food \/ Rural Business, Retail Management"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "institute of management pt. ravishankar shukla university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "raipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|19:NA|1:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, JMAT, CAT, CMAT",
    "tution_fees_local_country_student": 250000,
    "program_duration": 2,
    "institute_name": "dr. b. c. roy engineering college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "durgapur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "3:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT",
    "tution_fees_local_country_student": 166000,
    "program_duration": 2,
    "institute_name": "the icfai university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "chattisgarh",
    "city_name": "raipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "10:NA|1:NA|10:NA|5:NA|6:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, CAT, Others, GMAT, GRE, Others",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "the icfai university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "sikkim",
    "city_name": "gangtok",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|11:NA|18:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT, ATMA, JMET",
    "tution_fees_local_country_student": 400000,
    "program_duration": 2,
    "institute_name": "jyotirmoy school of business",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "eastern institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "4:NA|1:NA|2:NA|19:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, XAT, JMAT, CMAT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "ims business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 5:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, GMAT",
    "tution_fees_local_country_student": 550000,
    "program_duration": 2,
    "institute_name": "svran apeejay institute of management and design",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 74000,
    "program_duration": 2,
    "institute_name": "dronacharya institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "kurukshetra",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 86000,
    "program_duration": 2,
    "institute_name": "hindu institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "sonepat",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 91000,
    "program_duration": 2,
    "institute_name": "shri krishan institute of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "kurukshetra",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, CMAT",
    "tution_fees_local_country_student": 90000,
    "program_duration": 2,
    "institute_name": "haryana engineering college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "yamunanagar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT",
    "tution_fees_local_country_student": 75000,
    "program_duration": 2,
    "institute_name": "kurukshetra institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "pehowa",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "ngf college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "faridabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 166000,
    "program_duration": 2,
    "institute_name": "gurgaon institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "gurgaon",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|1:NA|11:NA|18:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, CAT, ATMA, JMET",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "ramanujan college of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "palwal",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|1:NA|11:NA|18:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, CAT, ATMA, JMET",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "ramanujan college of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "palwal",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "4:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, XAT",
    "tution_fees_local_country_student": 180000,
    "program_duration": 2,
    "institute_name": "guru gram business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "haryana",
    "city_name": "faridabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 134000,
    "program_duration": 2,
    "institute_name": "shriram institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "roorkee",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, CAT",
    "tution_fees_local_country_student": 110000,
    "program_duration": 2,
    "institute_name": "department of management studies kumaun university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "bhimtal",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "vision school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "chittorgarh",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT",
    "tution_fees_local_country_student": 144000,
    "program_duration": 2,
    "institute_name": "shri vaishnav institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "laxmipati institute of science and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "bhopal",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA|4:NA|11:NA|2:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, ATMA, XAT, CMAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "vns business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "bhopal",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "pt. jawaharlal nehru of business management vikram university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "ujjain",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "gyan ganga college of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "jabalpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|3:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, MAT",
    "tution_fees_local_country_student": 252000,
    "program_duration": 2,
    "institute_name": "teerthanker mahaveer institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "moradabad",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, ATMA",
    "tution_fees_local_country_student": 172000,
    "program_duration": 2,
    "institute_name": "iec college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, ATMA",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "institute of management and research",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA|15:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, ATMA, UPSEE",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "institute of management and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "lakshmi narain college of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "ewing christian institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "allahabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 136000,
    "program_duration": 2,
    "institute_name": "lal bahadur shastri institute of management and development studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA|18:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, ATMA, JMET, CMAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "sherwood business school",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "faizabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, Others",
    "tution_fees_local_country_student": 173000,
    "program_duration": 2,
    "institute_name": "hindustan institute of management and computer studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "mathura",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 170000,
    "program_duration": 2,
    "institute_name": "institute of computer science and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "varanasi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "institute of management education",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "1:NA|4:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, CMAT",
    "tution_fees_local_country_student": 173000,
    "program_duration": 2,
    "institute_name": "bsa college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "mathura",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 192000,
    "program_duration": 2,
    "institute_name": "maharana pratap engineering college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanth",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "pranveer singh institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "subharti institute of management and commerce",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, General Management"
  },
  {
    "test_cutoff": "3:NA|1:NA|4:NA|15:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, MAT, UPSEE",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "shri ram institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "muzaffarnagar",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 163000,
    "program_duration": 2,
    "institute_name": "aryakul college of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 130000,
    "program_duration": 2,
    "institute_name": "trivedi institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "fatehpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "sir madanlal institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ekdil",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "institute of pharmaceutical sciences and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "unnao",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "naraina vidya peeth management institute",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 181000,
    "program_duration": 2,
    "institute_name": "aryakul college of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "3:NA|4:NA|1:NA|2:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, MAT, CAT, XAT, ATMA",
    "tution_fees_local_country_student": 180000,
    "program_duration": 2,
    "institute_name": "sai ram institute of business and management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "mathura",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 1025000,
    "program_duration": 2,
    "institute_name": "jaipuria institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business, Retail Management"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, GMAT",
    "tution_fees_local_country_student": 975000,
    "program_duration": 2,
    "institute_name": "krupanidhi school of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Information Technology, Business Analytics, Healthcare \/ Hospital \/ Pharma, International Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 5:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, GMAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 1100000,
    "program_duration": 2,
    "institute_name": "prin l.n. welingkar institute of management development and research",
    "program_name": "post graduate diploma in business design management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Others"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 5:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 800000,
    "program_duration": 2,
    "institute_name": "taxila business school",
    "program_name": "post graduate diploma in data analytics management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jaipur",
    "program_duration_text": "2 Years",
    "specialization_name": "Information Technology"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|3:NA|8:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, XAT, CMAT, NMAT, CAT",
    "tution_fees_local_country_student": 1157000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Power \/ Energy \/ Oil \/ Gas"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|3:NA|8:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, XAT, CMAT, NMAT, CAT",
    "tution_fees_local_country_student": 1157000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Power \/ Energy \/ Oil \/ Gas"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|3:NA|8:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, XAT, CMAT, NMAT, CAT",
    "tution_fees_local_country_student": 1157000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "International Business"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|3:NA|8:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, XAT, CMAT, NMAT, CAT",
    "tution_fees_local_country_student": 1157000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Power \/ Energy \/ Oil \/ Gas"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|3:NA|8:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, XAT, CMAT, NMAT, CAT",
    "tution_fees_local_country_student": 1157000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Business Analytics"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|3:NA|8:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, XAT, CMAT, NMAT, CAT",
    "tution_fees_local_country_student": 1157000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Operations \/ SCM \/ Production"
  },
  {
    "test_cutoff": "10:NA|4:NA|2:NA|3:NA|8:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, XAT, CMAT, NMAT, CAT",
    "tution_fees_local_country_student": 1157000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Operations \/ SCM \/ Production"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 8:NA | 10:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, NMAT, Others",
    "tution_fees_local_country_student": 1236000,
    "program_duration": 2,
    "institute_name": "university of petroleum and energy studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttarakhand",
    "city_name": "dehradun",
    "program_duration_text": "2 Years",
    "specialization_name": "Infrastructure \/ Real Estate"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA|4:NA|7:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 725000,
    "program_duration": 2,
    "institute_name": "ramachandran international institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, XAT",
    "tution_fees_local_country_student": 180000,
    "program_duration": 2,
    "institute_name": "aryans business school ",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "patiala",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Business Analytics"
  },
  {
    "test_cutoff": "4:NA|3:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, CAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "som lalit institute of management studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "gujarat",
    "city_name": "ahmedabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT",
    "tution_fees_local_country_student": 90000,
    "program_duration": 2,
    "institute_name": "acn college of engineering and management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "aligarh",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "devprayag institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "allahabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 4:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, MAT, KMAT",
    "tution_fees_local_country_student": 116000,
    "program_duration": 2,
    "institute_name": "hmfa memorial institute of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "allahabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|7:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MH-CET",
    "tution_fees_local_country_student": 186000,
    "program_duration": 2,
    "institute_name": "mahatma gandhi mission institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "aurangabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|5:NA|11:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, GMAT, ATMA, Others",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "shreeyash college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "aurangabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA  | 3:NA  | 4:NA  | 11:NA  | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, MAT, ATMA",
    "tution_fees_local_country_student": 1448000,
    "program_duration": 2,
    "institute_name": "indian institute of plantation management",
    "program_name": "post graduate diploma in food processing and business management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "bangalore",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|16:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, TANCET",
    "tution_fees_local_country_student": 150000,
    "program_duration": 2,
    "institute_name": "guru nanak college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "chennai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "3:NA|1:NA|14:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, KMAT",
    "tution_fees_local_country_student": 240000,
    "program_duration": 2,
    "institute_name": "adi shankara institute of engineering technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "3:NA|1:NA|14:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, KMAT",
    "tution_fees_local_country_student": 280000,
    "program_duration": 2,
    "institute_name": "bharata mata college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "3:NA|1:NA|14:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, KMAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "de paul institute of science and technology school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "14:NA|3:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "KMAT, CMAT, CAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "de paul institute of science and technology school of management",
    "program_name": "master of human resource management",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "14:NA|3:NA|1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "KMAT, CMAT, CAT, MAT",
    "tution_fees_local_country_student": 110000,
    "program_duration": 2,
    "institute_name": "jai bharath school of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "mar thoma school of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "3:NA|4:NA|1:NA|14:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, MAT, CAT, KMAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "rajagiri centre for business studies",
    "program_name": "master of human resource management",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "3:NA|4:NA|1:NA|14:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, MAT, CAT, KMAT",
    "tution_fees_local_country_student": 650000,
    "program_duration": 2,
    "institute_name": "rajagiri centre for business studies",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, General Management, International Business"
  },
  {
    "test_cutoff": "14:NA|1:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "KMAT, CAT, CMAT",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "rural academy for management studies rams",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "3:NA|1:NA|14:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, KMAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "sree narayana gurukulam college of engineering",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "3:NA|14:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, KMAT, CAT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "viswajyothi school of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "cochin",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "16:NA|10:NA|4:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "TANCET, Others, MAT, CAT",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "vivekananda institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 150000,
    "program_duration": 2,
    "institute_name": "adithya institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "16:NA|5:NA|1:NA|2:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "TANCET, GMAT, CAT, XAT, MAT",
    "tution_fees_local_country_student": 220000,
    "program_duration": 2,
    "institute_name": "d.j. academy for managerial excellence",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "dr g r damodaran institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|1:NA|16:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, CAT, TANCET, Others",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "guruvayurappan institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Healthcare \/ Hospital \/ Pharma, Media & Communication"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "happy valley business school",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|5:NA|3:NA|11:NA|16:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, GMAT, CMAT, ATMA, TANCET",
    "tution_fees_local_country_student": 520000,
    "program_duration": 2,
    "institute_name": "jansons school of business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "16:NA|4:NA|2:NA|11:NA|10:NA|1:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "TANCET, MAT, XAT, ATMA, Others, CAT, Others",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "k v institute of management and information studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Digital Media"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "ranganathan engineering college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 100000,
    "program_duration": 2,
    "institute_name": "sasi creative school of architecture and business",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources"
  },
  {
    "test_cutoff": "16:NA|1:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "TANCET, CAT, Others",
    "tution_fees_local_country_student": 162000,
    "program_duration": 2,
    "institute_name": "snt global academy of management studies and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "sree saraswathi thyagaraja college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|1:NA|2:NA|3:NA|16:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, XAT, CMAT, TANCET",
    "tution_fees_local_country_student": 600000,
    "program_duration": 2,
    "institute_name": "sri krishna college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "tamil nadu",
    "city_name": "coimbatore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, Others",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "ajay binay institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "cuttack",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources, Retail Management"
  },
  {
    "test_cutoff": "4:NA|1:NA|2:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, XAT, Others",
    "tution_fees_local_country_student": 168000,
    "program_duration": 2,
    "institute_name": "barabati institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "cuttack",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "10:NA|4:NA|1:NA|2:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, MAT, CAT, XAT, CMAT",
    "tution_fees_local_country_student": 162000,
    "program_duration": 2,
    "institute_name": "dhaneswar rath institute of engineering and management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "cuttack",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "10:NA|1:NA|2:NA|4:NA|3:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "Others, CAT, XAT, MAT, CMAT, ATMA",
    "tution_fees_local_country_student": 120000,
    "program_duration": 2,
    "institute_name": "institute of professional studies and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "cuttack",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|4:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, Others",
    "tution_fees_local_country_student": 250000,
    "program_duration": 2,
    "institute_name": "kushagra institute of information and management science",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "cuttack",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 560000,
    "program_duration": 2,
    "institute_name": "sri sri university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "cuttack",
    "program_duration_text": "2 Years",
    "specialization_name": "Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 660000,
    "program_duration": 2,
    "institute_name": "sri sri university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "orissa",
    "city_name": "cuttack",
    "program_duration_text": "2 Years",
    "specialization_name": "Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 88000,
    "program_duration": 2,
    "institute_name": "deen dayal upadhyay gorakhpur university",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "gorakhpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 116000,
    "program_duration": 2,
    "institute_name": "kipm college of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "gorakhpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "11:NA|10:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "ATMA, Others, CAT",
    "tution_fees_local_country_student": 70000,
    "program_duration": 2,
    "institute_name": "astral institute of technology and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 114000,
    "program_duration": 2,
    "institute_name": "international institute of professional studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, ATMA",
    "tution_fees_local_country_student": 90000,
    "program_duration": 2,
    "institute_name": "sahib institute of management and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "shri atal bihari vajpayee government arts and commerce college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 100000,
    "program_duration": 2,
    "institute_name": "sri aurobindo institute of management and science",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "indore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, ATMA",
    "tution_fees_local_country_student": 90000,
    "program_duration": 2,
    "institute_name": "vikrant institute of business management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "madhya pradesh",
    "city_name": "gwalior",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT",
    "tution_fees_local_country_student": 114000,
    "program_duration": 2,
    "institute_name": "vyas institutes of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jodhpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Hospitality \/ Tourism, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT",
    "tution_fees_local_country_student": 100000,
    "program_duration": 2,
    "institute_name": "vyas institutes of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "rajasthan",
    "city_name": "jodhpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Power \/ Energy \/ Oil \/ Gas, Retail Management"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT",
    "tution_fees_local_country_student": 161000,
    "program_duration": 2,
    "institute_name": "bansi college of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "kanpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA|19:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, ATMA, JMAT",
    "tution_fees_local_country_student": 275000,
    "program_duration": 2,
    "institute_name": "institute of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|19:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, JMAT",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "meghnad saha institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 450000,
    "program_duration": 2,
    "institute_name": "netaji subhash engineering college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "19:NA|4:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "JMAT, MAT, CAT",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "seacom engineering college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "howrah",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA|3:NA|4:NA|2:NA|19:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, MAT, XAT, JMAT",
    "tution_fees_local_country_student": 380000,
    "program_duration": 2,
    "institute_name": "swami vivekananda institute of management and computer science",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "west bengal",
    "city_name": "kolkata",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "15:NA|1:NA|4:NA|2:NA|11:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "UPSEE, CAT, MAT, XAT, ATMA, Others",
    "tution_fees_local_country_student": 127000,
    "program_duration": 2,
    "institute_name": "aryavart institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA|3:NA|15:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, ATMA, CMAT, UPSEE",
    "tution_fees_local_country_student": 92000,
    "program_duration": 2,
    "institute_name": "basudev institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "15:NA|1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "UPSEE, CAT, MAT",
    "tution_fees_local_country_student": 290000,
    "program_duration": 2,
    "institute_name": "g.c.r.g group of institutions",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "15:NA|1:NA|4:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "UPSEE, CAT, MAT, Others",
    "tution_fees_local_country_student": 148000,
    "program_duration": 2,
    "institute_name": "global school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 161000,
    "program_duration": 2,
    "institute_name": "himalayan institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, ATMA",
    "tution_fees_local_country_student": 190000,
    "program_duration": 2,
    "institute_name": "institute of management research and technology",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "institute of management research and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|3:NA|5:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, CMAT, GMAT, ATMA",
    "tution_fees_local_country_student": 360000,
    "program_duration": 2,
    "institute_name": "international institute for special education",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 187000,
    "program_duration": 2,
    "institute_name": "noble institute of management and technology. lucknow",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Operations \/ SCM \/ Production, Information Technology, Infrastructure \/ Real Estate"
  },
  {
    "test_cutoff": "15:NA|1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "UPSEE, CAT, MAT",
    "tution_fees_local_country_student": 116000,
    "program_duration": 2,
    "institute_name": "rameshwaram institute of technology and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "15:NA|1:NA|4:NA|3:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "UPSEE, CAT, MAT, CMAT",
    "tution_fees_local_country_student": 183000,
    "program_duration": 2,
    "institute_name": "rameshwaram institute of technology and management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, Others",
    "tution_fees_local_country_student": 183000,
    "program_duration": 2,
    "institute_name": "s s institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|4:NA|2:NA|15:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, XAT, UPSEE",
    "tution_fees_local_country_student": 208000,
    "program_duration": 2,
    "institute_name": "sri ramswaroop memorial college of engineering and management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 208000,
    "program_duration": 2,
    "institute_name": "sri ramswaroop memorial college of engineering and management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "lucknow",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 140000,
    "program_duration": 2,
    "institute_name": "bhutta college of engineering and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "ludhiana",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 156000,
    "program_duration": 2,
    "institute_name": "gujrawala guru nanak institute of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "ludhiana",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 180000,
    "program_duration": 2,
    "institute_name": "gulzar group of institutes",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "ludhiana",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "3:NA|1:NA|4:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, MAT",
    "tution_fees_local_country_student": 195000,
    "program_duration": 2,
    "institute_name": "guru nanak dev engineering college",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "punjab",
    "city_name": "ludhiana",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 130000,
    "program_duration": 2,
    "institute_name": "m.e.s college of engineering",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "malappuram",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 300000,
    "program_duration": 2,
    "institute_name": "poornaprajna institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "manipal",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|1:NA|2:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, CAT, XAT, GMAT",
    "tution_fees_local_country_student": 676000,
    "program_duration": 2,
    "institute_name": "school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "manipal",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "3:NA|1:NA|4:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, MAT, ATMA",
    "tution_fees_local_country_student": 190000,
    "program_duration": 2,
    "institute_name": "g.h. raisoni school of business management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "4:NA|1:NA|3:NA|14:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 315000,
    "program_duration": 2,
    "institute_name": "bhavan's priyamvada birla institute of management",
    "program_name": "post graduate diploma in management",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "mysore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 200000,
    "program_duration": 2,
    "institute_name": "jss centre for management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "karnataka",
    "city_name": "mysore",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "4:NA|3:NA|11:NA|1:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, CMAT, ATMA, CAT, XAT",
    "tution_fees_local_country_student": 101000,
    "program_duration": 2,
    "institute_name": "central india college of business management and studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "nagpur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, International Business"
  },
  {
    "test_cutoff": "7:NA|1:NA|4:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MH-CET, CAT, MAT, XAT",
    "tution_fees_local_country_student": 160000,
    "program_duration": 2,
    "institute_name": "aditya institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Human Resources, International Business"
  },
  {
    "test_cutoff": "1:NA|5:NA|8:NA|2:NA|6:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, GMAT, NMAT, XAT, GRE",
    "tution_fees_local_country_student": 1400000,
    "program_duration": 2,
    "institute_name": "school of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "Greater Noida",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Business Analytics, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "3:NA|1:NA|4:NA|2:NA|18:NA|11:NA|10:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CMAT, CAT, MAT, XAT, JMET, ATMA, Others, Others",
    "tution_fees_local_country_student": 240000,
    "program_duration": 2,
    "institute_name": "dr. d. y. patil center for management and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 4:NA | 7:NA | 11:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, MAT, MH-CET, ATMA",
    "tution_fees_local_country_student": 171000,
    "program_duration": 2,
    "institute_name": "rajgad institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 2:NA | 3:NA | 4:NA | 10:NA | 11:NA | 18:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, Others, ATMA, JMET",
    "tution_fees_local_country_student": 194000,
    "program_duration": 2,
    "institute_name": "dr. d. y. patil center for management and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "1:NA|2:NA|3:NA|4:NA|7:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, MAT, MH-CET",
    "tution_fees_local_country_student": 172000,
    "program_duration": 2,
    "institute_name": "unique institute of management",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "7:NA|1:NA|18:NA|4:NA|11:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MH-CET, CAT, JMET, MAT, ATMA, XAT",
    "tution_fees_local_country_student": 190000,
    "program_duration": 2,
    "institute_name": "zeal college of engineering and research",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "pune",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, Healthcare \/ Hospital \/ Pharma, Hospitality \/ Tourism, Agri \/ Food \/ Rural Business, International Business, Retail Management, Media & Communication, Digital Media, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "7:NA|11:NA|1:NA|4:NA|2:NA|3:NA|5:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MH-CET, ATMA, CAT, MAT, XAT, CMAT, GMAT",
    "tution_fees_local_country_student": 92000,
    "program_duration": 2,
    "institute_name": "rajeev gandhi college of management studies",
    "program_name": "master in management studies",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "navi mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA|4:NA|18:NA|11:NA|2:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, MAT, JMET, ATMA, XAT, ",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "rohidas patil institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "bhor",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Human Resources"
  },
  {
    "test_cutoff": "1:NA | 3:NA | 14:NA | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, KMAT",
    "tution_fees_local_country_student": 180000,
    "program_duration": 2,
    "institute_name": "elijah institute of management studies",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "thrissur",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources, International Business"
  },
  {
    "test_cutoff": "15:NA|3:NA|4:NA|1:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "UPSEE, CMAT, MAT, CAT",
    "tution_fees_local_country_student": 90000,
    "program_duration": 2,
    "institute_name": "faculty of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "varanasi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Human Resources"
  },
  {
    "test_cutoff": "15:NA|1:NA|4:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "UPSEE, CAT, MAT, Others",
    "tution_fees_local_country_student": 240000,
    "program_duration": 2,
    "institute_name": "kashi institute of technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "varanasi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Information Technology, Human Resources, Agri \/ Food \/ Rural Business, International Business"
  },
  {
    "test_cutoff": "15:NA|1:NA|10:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "UPSEE, CAT, Others",
    "tution_fees_local_country_student": 150000,
    "program_duration": 2,
    "institute_name": "saraswati higher education and technical college of engineering",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "varanasi",
    "program_duration_text": "2 Years",
    "specialization_name": "Finance, Marketing, Operations \/ SCM \/ Production, Information Technology, Human Resources, International Business"
  },
  {
    "test_cutoff": "4:NA|2:NA|1:NA|11:NA",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "MAT, XAT, CAT, ATMA",
    "tution_fees_local_country_student": 140000,
    "program_duration": 2,
    "institute_name": "nef college of management and technology",
    "program_name": "master of business administration",
    "country_name": "India",
    "state_name": "assam",
    "city_name": "guwahati",
    "program_duration_text": "2 Years",
    "specialization_name": "Marketing, Human Resources, Entrepreneurship & Family Business"
  },
  {
    "test_cutoff": "",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, GMAT, GRE",
    "tution_fees_local_country_student": 2250000,
    "program_duration": 1,
    "institute_name": "indian institute of management kozhikode",
    "program_name": "post graduate program in business leadership (pgp-bl)",
    "country_name": "India",
    "state_name": "kerala",
    "city_name": "kozhikode",
    "program_duration_text": "1 Year",
    "specialization_name": "General Management"
  },
  {
    "test_cutoff": "",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "institute of management studies",
    "program_name": "post graduate diploma in international business",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "International Business"
  },
  {
    "test_cutoff": "",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, CMAT, MAT, GMAT, ATMA",
    "tution_fees_local_country_student": 795000,
    "program_duration": 2,
    "institute_name": "institute of management studies",
    "program_name": "post graduate diploma in big data analytics",
    "country_name": "India",
    "state_name": "uttar pradesh",
    "city_name": "ghaziabad",
    "program_duration_text": "2 Years",
    "specialization_name": "Big Data Analytics"
  },
  {
    "test_cutoff": "1:83 | 2:73 | 3:98 | 5:  500 | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1629279,
    "program_duration": 2,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration (healthcare management)",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Healthcare \/ Hospital \/ Pharma"
  },
  {
    "test_cutoff": "1:83  | 2:73  | 3:98  | 5:500  | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1629279,
    "program_duration": 2,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration (human resources)",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Human Resources"
  },
  {
    "test_cutoff": "1:83 | 2:73 | 3:98 | 5:500 | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1629279,
    "program_duration": 2,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration (sports management)",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Sports"
  },
  {
    "test_cutoff": "1:83 | 2:73 | 3:98 | 5:500 | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 1629279,
    "program_duration": 1,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration -executive",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "1 Year",
    "specialization_name": "Executive"
  },
  {
    "test_cutoff": "1:83 | 2:73 | 3:98 | 5:500 | ",
    "final_placements_domestic_salary_avg": 0,
    "tests_accepted": "CAT, XAT, CMAT, GMAT, NMAT",
    "tution_fees_local_country_student": 0,
    "program_duration": 2,
    "institute_name": "k j somaiya institute of management",
    "program_name": "master of business administration in data science & analytics",
    "country_name": "India",
    "state_name": "maharashtra",
    "city_name": "mumbai",
    "program_duration_text": "2 Years",
    "specialization_name": "Data Sciences"
  }
]

# %%
tests=['IBSAT',
 'NMAT',
 'GRE',
 'XAT',
 'CAT',
 'ATMA',
 'JMET',
 'TANCET',
 'IIFT',
 'KMAT',
 'GMAT',
 'CMAT',
 'Others',
 'PGCET',
 'MAT',
 'MICAT',
 'JMAT',
 'UPSEE',
 'IRMASAT']

# %%
import json
d=dict.fromkeys(tests,[])
for test in tests:
    for college in data_college:
        if test in college['tests_accepted']:
            d[test].append(college['institute_name'])
            
for k,v in d.items():
    d[k]=list(set(v))
    
to_write=json.dumps(d)

with open("tests.json",'w',encoding="UTF-8") as f:
    f.write(to_write)
